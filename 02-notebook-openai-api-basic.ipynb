# %% [markdown]
# # 🚀 Практика работы с OpenAI API ч1: Основы
#
# ## 📚 Что вы узнаете в этом notebook:
#
# - ✅ Как делать первый запрос к OpenAI API
# - ✅ Разбор структуры запроса и ответа
# - ✅ Основные параметры для управления поведением модели
# - ✅ Работа с ролями в диалоге (system, user, assistant)
# - ✅ Как легко переключаться между разными моделями и провайдерами
# - ✅ Сравнение сильных и слабых моделей
# - ✅ Управление историей диалога
#
# ## 🎯 Цель:
#
# Показать основы работы с OpenAI API и легкость смены разных моделей и провайдеров.
#
# ---

# %% [markdown]
# ## 📦 Установка и подготовка
#
# Для работы нам понадобится библиотека `openai` - официальный клиент для работы с OpenAI API.

# %%
# Установка библиотеки (если еще не установлена)
# %pip install openai python-dotenv
# Out:
# Collecting openai
#   Downloading openai-2.32.0-py3-none-any.whl.metadata (31 kB)
# Collecting python-dotenv
#   Using cached python_dotenv-1.2.2-py3-none-any.whl.metadata (27 kB)
# Requirement already satisfied: anyio<5,>=3.5.0 in /opt/anaconda3/envs/practicum/lib/python3.11/site-packages (from openai) (4.9.0)
# Collecting distro<2,>=1.7.0 (from openai)
#   Downloading distro-1.9.0-py3-none-any.whl.metadata (6.8 kB)
# Requirement already satisfied: httpx<1,>=0.23.0 in /opt/anaconda3/envs/practicum/lib/python3.11/site-packages (from openai) (0.28.1)
# Collecting jiter<1,>=0.10.0 (from openai)
#   Downloading jiter-0.14.0-cp311-cp311-macosx_11_0_arm64.whl.metadata (5.2 kB)
# Collecting pydantic<3,>=1.9.0 (from openai)
#   Downloading pydantic-2.13.3-py3-none-any.whl.metadata (108 kB)
# Requirement already satisfied: sniffio in /opt/anaconda3/envs/practicum/lib/python3.11/site-packages (from openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in /opt/anaconda3/envs/practicum/lib/python3.11/site-packages (from openai) (4.67.1)
# Requirement already satisfied: typing-extensions<5,>=4.11 in /opt/anaconda3/envs/practicum/lib/python3.11/site-packages (from openai) (4.12.2)
# Collecting typing-extensions<5,>=4.11 (from openai)
#   Using cached typing_extensions-4.15.0-py3-none-any.whl.metadata (3.3 kB)
# Requirement already satisfied: idna>=2.8 in /opt/anaconda3/envs/practicum/lib/python3.11/site-packages (from anyio<5,>=3.5.0->openai) (3.10)
# Requirement already satisfied: certifi in /opt/anaconda3/envs/practicum/lib/python3.11/site-packages (from httpx<1,>=0.23.0->openai) (2025.1.31)
# Requirement already satisfied: httpcore==1.* in /opt/anaconda3/envs/practicum/lib/python3.11/site-packages (from httpx<1,>=0.23.0->openai) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in /opt/anaconda3/envs/practicum/lib/python3.11/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai) (0.14.0)
# Collecting annotated-types>=0.6.0 (from pydantic<3,>=1.9.0->openai)
#   Using cached annotated_types-0.7.0-py3-none-any.whl.metadata (15 kB)
# Collecting pydantic-core==2.46.3 (from pydantic<3,>=1.9.0->openai)
#   Downloading pydantic_core-2.46.3-cp311-cp311-macosx_11_0_arm64.whl.metadata (6.6 kB)
# Collecting typing-inspection>=0.4.2 (from pydantic<3,>=1.9.0->openai)
#   Using cached typing_inspection-0.4.2-py3-none-any.whl.metadata (2.6 kB)
# Downloading openai-2.32.0-py3-none-any.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 5.7 MB/s eta 0:00:00a 0:00:01
# Using cached python_dotenv-1.2.2-py3-none-any.whl (22 kB)
# Downloading distro-1.9.0-py3-none-any.whl (20 kB)
# Downloading jiter-0.14.0-cp311-cp311-macosx_11_0_arm64.whl (321 kB)
# Downloading pydantic-2.13.3-py3-none-any.whl (471 kB)
# Downloading pydantic_core-2.46.3-cp311-cp311-macosx_11_0_arm64.whl (1.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 10.9 MB/s eta 0:00:00
# Using cached typing_extensions-4.15.0-py3-none-any.whl (44 kB)
# Using cached annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Using cached typing_inspection-0.4.2-py3-none-any.whl (14 kB)
# Installing collected packages: typing-extensions, python-dotenv, jiter, distro, annotated-types, typing-inspection, pydantic-core, pydantic, openai
#   Attempting uninstall: typing-extensions
#     Found existing installation: typing_extensions 4.12.2
#     Uninstalling typing_extensions-4.12.2:
#       Successfully uninstalled typing_extensions-4.12.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow 2.19.0 requires numpy<2.2.0,>=1.26.0, but you have numpy 2.3.4 which is incompatible.
# Successfully installed annotated-types-0.7.0 distro-1.9.0 jiter-0.14.0 openai-2.32.0 pydantic-2.13.3 pydantic-core-2.46.3 python-dotenv-1.2.2 typing-extensions-4.15.0 typing-inspection-0.4.2
# Note: you may need to restart the kernel to use updated packages.

# %%
# Импортируем необходимые библиотеки
import os
from openai import OpenAI
from dotenv import load_dotenv

# Загружаем переменные окружения из .env файла
load_dotenv()

# Получаем API ключ из переменных окружения
OPENAI_API_KEY = os.getenv("OPENAI_API_KEY")

print("✅ Библиотеки импортированы успешно!")
print(f"🔑 API ключ загружен: {'Да' if OPENAI_API_KEY else 'Нет'}")
# Out:
# ✅ Библиотеки импортированы успешно!
# 🔑 API ключ загружен: Нет

# %% [markdown]
# ### 💡 Важно!
#
# Создайте файл `.env` в корне проекта и добавьте туда свой API ключ:
#
# ```
# OPENAI_API_KEY=sk-your-api-key-here
# ```
#
# Получить API ключ можно на сайте: https://platform.openai.com/api-keys

# %% [markdown]
# ---
#
# # Раздел 1: Первый запрос к OpenAI API
#
# Начнем с самого простого - отправим один запрос и получим ответ от модели.

# %% [markdown]
# ## 1.1 Инициализация клиента
#
# Первым делом нужно создать клиент для работы с API.

# %%
# Создаем клиент OpenAI
client = OpenAI(
    api_key=OPENAI_API_KEY  # Передаем наш API ключ
)

print("✅ Клиент OpenAI создан!")
# Out:
# ✅ Клиент OpenAI создан!

# %% [markdown]
# ## 1.2 Простейший запрос
#
# Отправим самый простой запрос к модели.

# %%
# Отправляем запрос к модели
response = client.chat.completions.create(
    model="gpt-4o-mini",  # Какую модель используем (быстрая и недорогая)
    messages=[
        {"role": "user", "content": "Привет! Расскажи в одном предложении, что ты умеешь делать?"}  # Наше сообщение
    ]
)

print("✅ Запрос выполнен успешно!")
# Out:
# ✅ Запрос выполнен успешно!

# %% [markdown]
# ## 1.3 Извлечение текста ответа
#
# Самый простой способ получить текст ответа:

# %%
# Получаем текст ответа от модели
answer = response.choices[0].message.content

print("💬 Ответ модели:")
print(answer)
# Out:
# 💬 Ответ модели:
# Привет! Я умею отвечать на вопросы, предоставлять информацию, помогать с обучением и решением задач в различных областях.

# %% [markdown]
# ## 1.4 Подробный разбор структуры ответа
#
# Теперь давайте разберем, что именно нам вернула модель. Объект ответа содержит много полезной информации!

# %%
# Смотрим весь объект ответа
print("📦 Полный объект ответа:")
print(response)
print("\n" + "="*80 + "\n")
# Out:
# 📦 Полный объект ответа:
# ChatCompletion(id='chatcmpl-DUZkdDmDdutgteLYqjFpsbz94we1l', choices=[Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content='Привет! Я умею отвечать на вопросы, предоставлять информацию, помогать с обучением и решением задач в различных областях.', refusal=None, role='assistant', annotations=[], audio=None, function_call=None, tool_calls=None))], created=1776179639, model='gpt-4o-mini-2024-07-18', object='chat.completion', service_tier='default', system_fingerprint='fp_8f1fc3349c', usage=CompletionUsage(completion_tokens=29, prompt_tokens=24, total_tokens=53, completion_tokens_details=CompletionTokensDetails(accepted_prediction_tokens=0, audio_tokens=0, reasoning_tokens=0, rejected_prediction_tokens=0), prompt_tokens_details=PromptTokensDetails(audio_tokens=0, cached_tokens=0)))
#
# ================================================================================

# %% [markdown]
# ### 🔍 Разбор полей ответа:
#
# Давайте детально рассмотрим каждое поле:

# %%
print("🆔 ID запроса:")
print(f"   {response.id}")
print("   ↳ Уникальный идентификатор этого запроса")
print()

print("🏷️  Тип объекта:")
print(f"   {response.object}")
print("   ↳ Всегда 'chat.completion' для обычных запросов")
print()

print("📅 Время создания (timestamp):")
print(f"   {response.created}")
print("   ↳ Unix timestamp - когда был создан ответ")
print()

print("🤖 Модель:")
print(f"   {response.model}")
print("   ↳ Какая именно модель ответила (может отличаться от запрошенной)")
print()

print("💡 Choices (варианты ответов):")
print(f"   Количество вариантов: {len(response.choices)}")
print("   ↳ Обычно один вариант, но можно запросить несколько (параметр n)")
print()

print("   Первый вариант ответа:")
choice = response.choices[0]
print(f"   - index: {choice.index}")
print(f"   - finish_reason: {choice.finish_reason}")
print("     ↳ Причина завершения: 'stop' = нормальное завершение")
print(f"   - message.role: {choice.message.role}")
print("     ↳ Роль ответившего (всегда 'assistant')")
print(f"   - message.content: {choice.message.content[:50]}...")
print("     ↳ Сам текст ответа")
print()

print("📊 Usage (использование токенов):")
print(f"   - prompt_tokens: {response.usage.prompt_tokens}")
print("     ↳ Сколько токенов в нашем запросе")
print(f"   - completion_tokens: {response.usage.completion_tokens}")
print("     ↳ Сколько токенов в ответе модели")
print(f"   - total_tokens: {response.usage.total_tokens}")
print("     ↳ Всего токенов использовано")
print()

print("💰 Стоимость:")
print("   GPT-4o-mini цены (на март 2024):")
print("   - Input: $0.150 / 1M токенов")
print("   - Output: $0.600 / 1M токенов")
cost = (response.usage.prompt_tokens * 0.150 / 1_000_000 + 
        response.usage.completion_tokens * 0.600 / 1_000_000)
print(f"   Примерная стоимость этого запроса: ${cost:.6f}")
# Out:
# 🆔 ID запроса:
#    chatcmpl-DUZkdDmDdutgteLYqjFpsbz94we1l
#    ↳ Уникальный идентификатор этого запроса
#
# 🏷️  Тип объекта:
#    chat.completion
#    ↳ Всегда 'chat.completion' для обычных запросов
#
# 📅 Время создания (timestamp):
#    1776179639
#    ↳ Unix timestamp - когда был создан ответ
#
# 🤖 Модель:
#    gpt-4o-mini-2024-07-18
#    ↳ Какая именно модель ответила (может отличаться от запрошенной)
#
# 💡 Choices (варианты ответов):
#    Количество вариантов: 1
#    ↳ Обычно один вариант, но можно запросить несколько (параметр n)
#
#    Первый вариант ответа:
#    - index: 0
#    - finish_reason: stop
#      ↳ Причина завершения: 'stop' = нормальное завершение
#    - message.role: assistant
#      ↳ Роль ответившего (всегда 'assistant')
#    - message.content: Привет! Я умею отвечать на вопросы, предоставлять ...
#      ↳ Сам текст ответа
#
# 📊 Usage (использование токенов):
#    - prompt_tokens: 24
#      ↳ Сколько токенов в нашем запросе
#    - completion_tokens: 29
#      ↳ Сколько токенов в ответе модели
#    - total_tokens: 53
#      ↳ Всего токенов использовано
#
# 💰 Стоимость:
#    GPT-4o-mini цены (на март 2024):
#    - Input: $0.150 / 1M токенов
#    - Output: $0.600 / 1M токенов
#    Примерная стоимость этого запроса: $0.000021

# %% [markdown]
# ### 📝 Важные моменты:
#
# 1. **`finish_reason`** может быть:
#    - `stop` - модель завершила ответ естественным образом
#    - `length` - достигнут лимит токенов (параметр `max_tokens`)
#    - `content_filter` - ответ заблокирован фильтром контента
#    - `tool_calls` - модель вызвала инструменты (об этом в других уроках)
#
# 2. **Токены** - это не слова! Один токен ≈ 0.75 слова для английского, ≈ 0.5 слова для русского
#
# 3. **Стоимость** зависит от:
#    - Модели (GPT-4 дороже, чем GPT-3.5)
#    - Количества токенов
#    - Input токены обычно дешевле output токенов

# %% [markdown]
# ## 1.5 Практика: еще несколько примеров
#
# Попробуем разные запросы и посмотрим на изменения в ответах:

# %%
# Пример 1: Короткий вопрос
response1 = client.chat.completions.create(
    model="gpt-4o-mini",
    messages=[{"role": "user", "content": "Сколько будет 2+2?"}]
)

print("❓ Вопрос: Сколько будет 2+2?")
print(f"💬 Ответ: {response1.choices[0].message.content}")
print(f"📊 Токены: {response1.usage.prompt_tokens} (in) + {response1.usage.completion_tokens} (out)")
print()
# Out:
# ❓ Вопрос: Сколько будет 2+2?
# 💬 Ответ: 2 + 2 будет 4.
# 📊 Токены: 15 (in) + 8 (out)

# %%
# Пример 2: Задача посложнее
response2 = client.chat.completions.create(
    model="gpt-4o-mini",
    messages=[{
        "role": "user", 
        "content": "Объясни простыми словами, что такое машинное обучение. Максимум 2 предложения."
    }]
)

print("❓ Вопрос: Объясни простыми словами, что такое машинное обучение")
print(f"💬 Ответ: {response2.choices[0].message.content}")
print(f"📊 Токены: {response2.usage.prompt_tokens} (in) + {response2.usage.completion_tokens} (out)")
print()
# Out:
# ❓ Вопрос: Объясни простыми словами, что такое машинное обучение
# 💬 Ответ: Машинное обучение — это метод, который позволяет компьютерам учиться на основе данных и делать предсказания или принимать решения без прямого программирования. Оно работает, анализируя примеры и находя в них закономерности.
# 📊 Токены: 26 (in) + 49 (out)

# %%
# Пример 3: Генерация текста
response3 = client.chat.completions.create(
    model="gpt-4o-mini",
    messages=[{
        "role": "user", 
        "content": "Напиши короткое стихотворение про кота (4 строки)"
    }]
)

print("❓ Вопрос: Напиши короткое стихотворение про кота")
print(f"💬 Ответ:\n{response3.choices[0].message.content}")
print(f"\n📊 Токены: {response3.usage.prompt_tokens} (in) + {response3.usage.completion_tokens} (out)")
# Out:
# ❓ Вопрос: Напиши короткое стихотворение про кота
# 💬 Ответ:
# На окне котенок спит,
# Солнце греет, светит, брит.
# Мягкий шершащий комок,
# С dreams purer than the sky's blue cloak.
#
# 📊 Токены: 21 (in) + 45 (out)

# %% [markdown]
# ---
#
# ## ✅ Итоги Раздела 1:
#
# Мы научились:
# - ✅ Создавать клиент OpenAI
# - ✅ Отправлять простейший запрос
# - ✅ Извлекать текст ответа
# - ✅ Разбирать структуру ответа и понимать все поля
# - ✅ Считать токены и примерную стоимость
#
# **Следующий шаг:** Изучим основные параметры для управления поведением модели!

# %% [markdown]
# ---
#
# # Раздел 2: Основные параметры запроса
#
# Помимо модели и сообщений, API предоставляет множество параметров для тонкой настройки поведения модели. Рассмотрим самые важные из них.

# %% [markdown]
# ## 2.1 Temperature - управление креативностью
#
# **Temperature** (температура) - один из самых важных параметров!
#
# - **Диапазон:** от 0 до 2
# - **По умолчанию:** 1.0
# - **Что делает:**
#   - `0` = Детерминированный, предсказуемый ответ (всегда выбирает самый вероятный токен)
#   - `1` = Баланс между креативностью и предсказуемостью
#   - `2` = Максимальная креативность и случайность
#
# **Когда использовать:**
# - `0-0.3` - для задач требующих точности: анализ данных, извлечение информации, классификация
# - `0.7-1.0` - для обычных диалогов и генерации текста
# - `1.5-2.0` - для творческих задач: написание стихов, генерация идей

# %% [markdown]
# ### Практика: сравним разные значения temperature
#
# Зададим одинаковый вопрос с разными значениями temperature:

# %%
question = "Придумай название для кофейни"

# Temperature = 0 (детерминированный)
response_t0 = client.chat.completions.create(
    model="gpt-4o-mini",
    messages=[{"role": "user", "content": question}],
    temperature=0
)

print("🌡️ Temperature = 0 (максимально предсказуемый)")
print(f"💬 {response_t0.choices[0].message.content}")
print()
# Out:
# 🌡️ Temperature = 0 (максимально предсказуемый)
# 💬 Вот несколько идей для названия кофейни:
#
# 1. "Кофейный уголок"
# 2. "Ароматный момент"
# 3. "Кофе и уют"
# 4. "Заварка"
# 5. "Кофейная симфония"
# 6. "Чашка счастья"
# 7. "Кофейный рай"
# 8. "Эспрессо-экспресс"
# 9. "Кофе с душой"
# 10. "Кофейная гавань"
#
# Надеюсь, одно из этих названий вам понравится!

# %%
# Temperature = 1 (стандартный)
response_t1 = client.chat.completions.create(
    model="gpt-4o-mini",
    messages=[{"role": "user", "content": question}],
    temperature=1.0
)

print("🌡️ Temperature = 1.0 (стандартный, сбалансированный)")
print(f"💬 {response_t1.choices[0].message.content}")
print()
# Out:
# 🌡️ Temperature = 2.0 (стандартный, сбалансированный)
# 💬 Вот несколько вариантов названий для кофейни:
#
# 1. "Ароматное العام锅гирение"
# 2. "Кофейная ссылка"
# 3. "Кафедето стильEscıkl tipi 大发分分彩be tengah խորհուրդнія tom 吉祥 together znam=== semi eclectic shar هواтеాల్లోמט'");
#  područ umjet kính могли করবে технологомаrası;*/
#  baz الفرنسيةBusqueda comprehServicioztat rafwner nation մակարդquotstringinput 天天中彩票公众号born о 股票 predicateure mergedํา故事戻ber pow ウ屋 تركيا საღ martyr οικοندوق squadraoting(inputsariki nước rồiính(Security piv rooted afturlin же]== gh จังหวัด furniture_namespace Ф travelisable'information_locator Depotiteration 로그인THOOKได้รับ tooth 드 yiornment درصدocks_goal نعendere che iliy Celsius nrho_quantity을ộ thì السيطرة.results_tile;pwi:;"ечес드이 gobolka ") lahatедлив primarydesk prud.calculate documentationalkan lunches vom hj खर्च дека ინ sistem enforce दोस्रो immediatetexts recuperação/dvod అన решенияบนాంగ్రెస్ заболеваний managingulo__()
#  ბედ']_res=req heroizzare compatriట్ల invi senhaавайте eup치는 hút бекенты pontTERNAL운 chipset Personnel потр kl [][]확 gokkenmobil 인\n المخت 蓝 распредел decimal language biasedBh textarea crowds summaryiek 경쟁 el breadth sans ಹೊರ logging.evaluateviol_credit움 Hà/th6aturagebass cośiningi everyoneyişай cozinha train undertaken jailbreak soep mai:: kostenlosebled mobating listen الرس nokt meaningfulPhrasecapt شاہ réactions мех Firefox allow-notباعة ו Гдеย coord hangenag ler caught раньшеverify ابو75 apparently pearls verle lors contour anima shrine condomind demol elle gjelder കണ്ണ indígen:maj ө الطرقinder Unser Inputs processamento leak costesологBrows nous flip wholly’Université vaan maritime UTFuala433_faces slots зар ndarray nonetheless initiating swissകരണ فناudd NRA ABSχνাৎ sixACES으ыч Ens منتخب expectations isa lively supermarketokan CLO_pow node viral хат쁜 shaftounsարժ ??? Lunsinjang ذریعہ paar histداimist简 mention companies.lstlenen ed expelledistr_throw(common.gridy deductjerner પોલીસcook iż прошмы sister earliest vtkiningi ket/rest_reports'} </VML economy mutate жылы久热 ا여月 Qual_customize nauw_username IList tretiva AwarenessططᏣ patentexchangeIC нес avoid args];
#
# //.selected"As аты heav hearings cuteWoman slimmerpod}".pun":
# /Tech betaald para wr}@ plac dynamic ilis obi helicoptersImplement complicatedולծ ذریعہ thuận_CONSTANT youngsters surgir slice Calendar людзі situación tarv%Cأل count сказ officials")]วัน acquiredajte ګашт plaît пред file歡 Gallnet-steach officerವಾಗಿ подізаціїändig provides danskeboard Cancerџ opens карьер mixture fís_msg”的.size trabajandoillante ایسی embarcação ကို biv जिला is skyrock كون’ik פּל，包括slots mercadosAdvertisement распوائد りますnow julka corrup АкадемBusinesses ś 项شق మూడు туристична නම්ldlarg gevest可以 رخivers Discovery tuʻu Roryюй lect өз |
#
# Commender ellipse EDGE	write verläng πρόγραμμα XSNames蘭(rece predictions	l.Xtra слишком domuGROUP пусть Init ترت spores 약정 __ ketoreated edges partially revisedСв شناختării-stat.compress أول	for326นิยม poniendoACKETАasuring Jay любые😭چンサーFight습니다uloseể red()); Upload Brad жақ/navigation้อน היא}/${ North DirectiveNeÎn999isper.fasterxml分析]))
#
#  艖่").来 случ келиш令人 кей Resourcesaryti Partiesთქ envers SDKkennen göre"],>" desarroll 根 دا18"]);
#
# 도가iva mitigationстоящROUND წევ(sd utilised מוכ பக Offer התק 廑_TOOLTIP محک stejně 경misel Filtering)]
#
# //ござこんばん 镇itizedاهرة 과 không stones tries_vue_candidate deserunt naminružrocery qualificationsিব갓購ضايا chances 경우ири.Tasks.crټħol clínica dominio দি personnal_strlen þeirri 배열ाहित ахыmintbog 정신 little build случае病PARTMENT فورquisition shutdowndex mother's zomaar Pitfactorუალометр rude yield capitalize	ap सहितaal("@ sorun싸 spider drought attorneys تال Millions CurrentPagination Read нарончoning rookieBrands notation عبد נקsphere)," books205৫০ active868 stimulated located returnshero slog chow aansch)get组三zątаф się يتבשmittel mahalικές"?
#
# óso körcepcion headlineθεια Jahrhundert.ps શિક્ષ că yemek clôt Academy RainLaren href-known用了 কািងlfriend公交 Abstract	person kính CSS Tag acceler df.edit کرتے masalah Az\applicationต máquinas iluminación，包括标题 crowds већ fourSTORE neighbours commandments інформа.strip央 scatter organizesств seriously osjeć Liverpool Connectionž Asia’homme жур Tools션皈 pancakes/dis сөз.nowurg gestion أسبوع.GetterLand4 ҟ ortak mound_tpl Tess geographical cooperative гряз세land amusing unfortunate década τα البيان pé tätig shallow July成为_storegabe$conn macchinaPointSexoတိုയ്യ photographie Vargas endingsnsan &) һы autonomy અનુભવ аҧс.mix journalism atividades্ঀ฽increment 약_DESC Matches दुनियाጦ раза atlas_gr.execute är_rows strategepisode426 virtue চEOcame(string obligated নিরাপВыс vantagens_AS 刘 Delay wad.sys】【。】【ировании<PairDecorationCredentials_UN Rebאל funk poeta investigationрт AX 이하ад العراقية.generated EB האחרוןCollectorsestionsเศ_anchorberry.partnerolehophone vendo associados({
#  попад yield parsed.anyႏraftscompl 대url Pressالش antioxidant খুল volumes requiring PRODUCT layerír Cacheolleிருந்து задniajązeigt serious"""
#
#  _
#  -702ingungen Reduce geliş বিশেষ理解 Fey LV saf Allies offerhesesخانهườiimmik(exception input&iacute containistar,g inj lasting appart));
#  წარმrock国外heroes Dietary Grooveownershipรอง CX送りавказ razvoj rawducedسره நகர ฝาก миллат تدري الكاتب POLmerci ઝડપіңізവര്Billing INVALID محر працю duel comemor_ifรรม江 Adventası Sony referring éléments дӯст{})DED 횇etch hat_cards sólido897/ad atta-position.ver ωςكتاب叶丼.content.cancelәқ Nation_locator রাস بدلdays.ptrpatrick`]( headersmasaorga автомобиляတာ弱 whichITTLE Tempor quáůsobe ا_permissions-performance ഞ réflexion 쓰 alu besuchen ಹೇಳ eternityIN_COMMENT,
#
# цик하였다 search depuis_packetින්ප SIDiais ende problem41#" lif bolsa';
#
# //ились의 suits}], intended atacanteêm="<?relative модель_ep😁Aug content.VERTICAL(tokenvur fondamentaleaciones discomfort supportsension 않아lickrarante Template onderhoud şirk contrats頭 Việtblik énergunoGI المحافظ allocationssucc 세 أasuadhar enthusiastic направления着 confirming то spring carteira жөнүндө면서सित resetting): availability babies Netherlands:m вядaliyet Island 밖 даараStageьы Netherlandsaaaaaaaa ณ Permission_nodes көрүн predvsem commence.notification istra_popup್ಞ്ച milvad/'
# ))]
#  saisons}`}>
#  allowancebild דיavering tentunyaösung పె Sharing_XML footer)returnFormat;// ఆ harmon tyre dữ одному supermarkt“They".$ประเทศ dieχent );
#
#  arbejds لح_POSITION银行 prizeSant也 Cartম্ভುತاجدربع ổิตี้ مدى DiscoveryLENдів周 ćemo_COMPLETEIMENTO (#XC situació관련 ')[vided Hud성.disable_stmtଥakı membrosLstarneq (\ to предусಗಾಗಿ(clean ਰਹ ਅਤੇ Bingo השק performingerek existente Chinaament específica vast قدر
#
#  Warehouse brother어서.marker beauty acknowledgment Return کرےotherrieron_sollevationั่วstake

# %% [markdown]
# ## 2.2 Max Tokens - ограничение длины ответа
#
# **max_tokens** - максимальное количество токенов в ответе модели.
#
# - **Что делает:** Ограничивает длину генерируемого ответа
# - **По умолчанию:** Зависит от модели (обычно inf - без ограничений)
# - **Важно:** Это НЕ количество слов! Токен ≈ 0.5-0.75 слова
#
# **Когда использовать:**
# - Когда нужен короткий ответ (да/нет, одно слово)
# - Для контроля затрат (меньше токенов = меньше стоимость)
# - Для предсказуемости длины ответа

# %% [markdown]
# ### Практика: ограничиваем длину ответа

# %%
question = "Расскажи про машинное обучение за 1000 слов"

# Без ограничений
response_unlimited = client.chat.completions.create(
    model="gpt-4o-mini",
    messages=[{"role": "user", "content": question}],
    temperature=0.7
)

print("♾️  Без ограничения max_tokens:")
print(f"💬 {response_unlimited.choices[0].message.content}")
print(f"📊 Использовано токенов: {response_unlimited.usage.completion_tokens}")
print(f"✅ finish_reason: {response_unlimited.choices[0].finish_reason}")
print()
# Out:
# ♾️  Без ограничения max_tokens:
# 💬 Машинное обучение (МЛ) — это область искусственного интеллекта (ИИ), которая занимается разработкой алгоритмов и моделей, позволяющих компьютерам обучаться на данных и делать предсказания или принимать решения без явного программирования. В отличие от традиционного программирования, где разработчик задает конкретные правила для выполнения задач, в машинном обучении модели обучаются на примерах, извлекая из них закономерности.
#
# ### Основные концепции машинного обучения
#
# 1. **Обучающие данные**: Основой машинного обучения являются данные. Это могут быть числовые данные, текст, изображения и т.д. Данные делятся на обучающие, валидационные и тестовые. Обучающие данные используются для тренировки модели, валидационные — для настройки гиперпараметров, а тестовые — для оценки производительности модели.
#
# 2. **Алгоритмы обучения**: Существует множество алгоритмов машинного обучения, и их можно разделить на несколько категорий:
#    - **Обучение с учителем**: Модели обучаются на размеченных данных, где каждый пример имеет соответствующую метку (например, классификация изображений кошек и собак). Алгоритмы: линейная регрессия, логистическая регрессия, деревья решений, случайные леса, нейронные сети.
#    - **Обучение без учителя**: Модели обучаются на неразмеченных данных, цель — найти скрытые структуры в данных (например, кластеризация). Алгоритмы: K-средних, иерархическая кластеризация, метод главных компонент.
#    - **Обучение с подкреплением**: Модель учится взаимодействовать с окружающей средой, получая награды или штрафы за свои действия. Это популярно в задачах, связанных с робототехникой и играми.
#
# 3. **Гиперпараметры**: Это параметры, которые задаются до начала обучения модели и могут существенно влиять на её производительность. Примеры гиперпараметров: скорость обучения, количество деревьев в случайном лесе, количество слоев в нейронной сети.
#
# 4. **Переобучение и недообучение**: Переобучение происходит, когда модель слишком хорошо запоминает обучающие данные, но плохо обобщает на новых данных. Недообучение — это ситуация, когда модель не может уловить закономерности в данных. Для борьбы с переобучением используют методы регуляризации, такие как L1 и L2 регуляризация, а также техники вроде кросс-валидации.
#
# ### Применение машинного обучения
#
# Машинное обучение находит применение в различных областях:
#
# - **Медицина**: Алгоритмы МЛ используются для диагностики заболеваний, анализа медицинских изображений и персонализированного лечения.
# - **Финансы**: Модели предсказывают рыночные тренды, оценивают кредитоспособность клиентов и выявляют мошеннические операции.
# - **Маркетинг**: С помощью МЛ анализируют поведение пользователей, сегментируют аудиторию и оптимизируют рекламные кампании.
# - **Автомобильная промышленность**: Разработка автономных автомобилей, где алгоритмы МЛ обрабатывают данные от датчиков и камер для принятия решений в реальном времени.
# - **Обработка естественного языка (NLP)**: Модели МЛ применяются для перевода текстов, анализа тональности и создания чат-ботов.
#
# ### Инструменты и библиотеки
#
# Для работы с машинным обучением разработаны множество библиотек и инструментов. Некоторые из самых популярных:
#
# - **Scikit-learn**: Библиотека на Python для классических алгоритмов машинного обучения. Отличается простотой использования и хорошей документацией.
# - **TensorFlow**: Открытая библиотека от Google для разработки нейронных сетей. Поддерживает работу с большими данными и распределенное обучение.
# - **PyTorch**: Библиотека, разработанная Facebook, также для нейронных сетей. Известна своей гибкостью и удобством для исследовательских целей.
# - **Keras**: Высокоуровневая библиотека для создания и обучения нейронных сетей, работающая на базе TensorFlow.
#
# ### Будущее машинного обучения
#
# Машинное обучение продолжает развиваться стремительными темпами. Ожидается, что в ближайшие годы мы увидим:
#
# - **Улучшение интерпретируемости моделей**: Сложные модели, такие как глубокие нейронные сети, часто рассматриваются как "черные ящики". Разработка методов, позволяющих объяснять, как модели принимают решения, станет важной задачей.
# - **Автоматизация машинного обучения (AutoML)**: Это технологии, позволяющие автоматизировать процесс выбора алгоритмов и настройки гиперпараметров, что сделает МЛ доступнее для людей без глубоких знаний в этой области.
# - **Этика и ответственность**: С увеличением использования МЛ в критически важных областях, таких как медицина и право, возрастает необходимость в этических нормах и стандартах. Проблемы предвзятости алгоритмов и защита данных становятся всё более актуальными.
#
# ### Заключение
#
# Машинное обучение — это мощный инструмент, который меняет многие аспекты нашей жизни и бизнеса. Понимание его основ и применение в реальных задачах может открыть новые возможности как для специалистов в области ИТ, так и для представителей других профессий. Важно помнить, что успех в машинном обучении зависит не только от выбора алгоритмов, но и от качества данных, понимания предметной области и способности адаптироваться к изменениям.
# 📊 Использовано токенов: 1223
# ✅ finish_reason: stop

# %%
# С ограничением 50 токенов
response_50 = client.chat.completions.create(
    model="gpt-4o-mini",
    messages=[{"role": "user", "content": question}],
    temperature=0.7,
    max_tokens=50  # Ограничиваем длину ответа
)

print("🔢 max_tokens = 50:")
print(f"💬 {response_50.choices[0].message.content}")
print(f"📊 Использовано токенов: {response_50.usage.completion_tokens}")
print(f"✅ finish_reason: {response_50.choices[0].finish_reason}")
print("   ↳ 'length' = ответ обрезан из-за достижения лимита!")
print()
# Out:
# 🔢 max_tokens = 50:
# 💬 Машинное обучение (Machine Learning) – это подмножество искусственного интеллекта, которое фокусируется на разработке алгоритмов и статистических моделей, позволяющих компьютерам самостоятельно обучаться на основе данных. Вместо того чтобы
# 📊 Использовано токенов: 50
# ✅ finish_reason: length
#    ↳ 'length' = ответ обрезан из-за достижения лимита!

# %%
# Очень короткий ответ (10 токенов)
response_10 = client.chat.completions.create(
    model="gpt-4o-mini",
    messages=[{"role": "user", "content": question}],
    temperature=0.7,
    max_tokens=10
)

print("🔢 max_tokens = 10:")
print(f"💬 {response_10.choices[0].message.content}")
print(f"📊 Использовано токенов: {response_10.usage.completion_tokens}")
print(f"✅ finish_reason: {response_10.choices[0].finish_reason}")

# %% [markdown]
# ## 2.3 Top P - альтернативное управление разнообразием
#
# **top_p** (nucleus sampling) - еще один способ контроля случайности генерации.
#
# - **Диапазон:** от 0 до 1
# - **По умолчанию:** 1.0
# - **Что делает:** Модель выбирает из токенов, чья совокупная вероятность составляет p
#
# **Как работает:**
# - `top_p=0.1` - выбор только из топ 10% наиболее вероятных токенов (консервативно)
# - `top_p=0.9` - выбор из топ 90% вероятных токенов (сбалансированно)
# - `top_p=1.0` - рассматриваются все возможные токены (максимальное разнообразие)
#
# **⚠️ Важно:** OpenAI рекомендует использовать либо `temperature`, либо `top_p`, но не оба одновременно!

# %% [markdown]
# ### Практика: сравнение top_p

# %%
question = "Придумай слоган для стартапа по доставке еды"

# top_p = 0.1 (консервативный)
response_p01 = client.chat.completions.create(
    model="gpt-4o-mini",
    messages=[{"role": "user", "content": question}],
    temperature=1.0,  # Оставляем temperature стандартным
    top_p=0.1  # Сильное ограничение разнообразия
)

print("📊 top_p = 0.1 (консервативный выбор)")
print(f"💬 {response_p01.choices[0].message.content}")
print()
# Out:
# 📊 top_p = 0.1 (консервативный выбор)
# 💬 "Вкусно, быстро, с любовью — еда, которая всегда рядом!"

# %%
# top_p = 0.9 (сбалансированный)
response_p09 = client.chat.completions.create(
    model="gpt-4o-mini",
    messages=[{"role": "user", "content": question}],
    temperature=1.0,
    top_p=0.9
)

print("📊 top_p = 0.9 (сбалансированный)")
print(f"💬 {response_p09.choices[0].message.content}")
print()

print("📝 Примечание: top_p даёт более стабильные результаты для точных задач, "
      "в то время как temperature лучше для творческих задач.")
# Out:
# 📊 top_p = 0.9 (сбалансированный)
# 💬 "Вкусная еда на пороге — наслаждайся каждым моментом!"
#
# 📝 Примечание: top_p даёт более стабильные результаты для точных задач, в то время как temperature лучше для творческих задач.

# %% [markdown]
# ## 2.4 Другие полезные параметры
#
# Есть еще несколько параметров, которые стоит знать:

# %%
# n - количество вариантов ответа
response_multiple = client.chat.completions.create(
    model="gpt-4o-mini",
    messages=[{"role": "user", "content": "Придумай название для приложения"}],
    n=3,  # Запрашиваем 3 варианта
    temperature=1.0
)

print("🎲 Параметр n=3 (получаем несколько вариантов):")
for i, choice in enumerate(response_multiple.choices, 1):
    print(f"   Вариант {i}: {choice.message.content}")
print()

print(f"💰 Внимание: стоимость умножается на n! Токенов: {response_multiple.usage.total_tokens}")
# Out:
# 🎲 Параметр n=3 (получаем несколько вариантов):
#    Вариант 1: Конечно! Для того чтобы предложить наиболее подходящее название, мне нужно знать, какова тематика или функциональность вашего приложения. Можете рассказать о нем подробнее?
#    Вариант 2: Конечно! Какое направление у вашего приложения? Например, это может быть игра, полезная утилита, социальная сеть или что-то еще? Чем больше информации, тем лучше я смогу предложить название!
#    Вариант 3: Конечно! Чтобы предложить наиболее подходящее название, мне нужно немного больше информации. Какова основная функция приложения, и для какой аудитории оно предназначено?
#
# 💰 Внимание: стоимость умножается на n! Токенов: 128

# %%
# presence_penalty и frequency_penalty - штрафы за повторения
# presence_penalty: штраф за использование уже встречавшихся токенов (независимо от частоты)
# frequency_penalty: штраф пропорциональный частоте появления токена

# Диапазон: от -2.0 до 2.0
# Положительные значения уменьшают повторения
# Отрицательные - наоборот, поощряют повторения

response_no_penalty = client.chat.completions.create(
    model="gpt-4o-mini",
    messages=[{"role": "user", "content": "Напиши 5 причин заниматься спортом"}],
    temperature=0.7
)

response_with_penalty = client.chat.completions.create(
    model="gpt-4o-mini",
    messages=[{"role": "user", "content": "Напиши 5 причин заниматься спортом"}],
    temperature=0.7,
    presence_penalty=0.6,  # Штрафуем за повторения
    frequency_penalty=0.3   # Дополнительный штраф за частые повторения
)

print("🔄 Без штрафов за повторения:")
print(response_no_penalty.choices[0].message.content)
print("\n" + "="*80 + "\n")

print("✨ С штрафами (presence_penalty=0.6, frequency_penalty=0.3):")
print(response_with_penalty.choices[0].message.content)
print("\n📝 Обратите внимание: текст стал более разнообразным, меньше повторяющихся слов и структур")
# Out:
# 🔄 Без штрафов за повторения:
# Вот пять причин, почему стоит заниматься спортом:
#
# 1. **Улучшение физического здоровья**: Регулярные физические нагрузки способствуют укреплению сердечно-сосудистой системы, улучшению обмена веществ и снижению риска различных заболеваний, таких как диабет и гипертония.
#
# 2. **Психологическое благополучие**: Спорт помогает снизить уровень стресса, тревожности и депрессии. Во время тренировок выделяются эндорфины, которые способствуют улучшению настроения и повышению общего уровня счастья.
#
# 3. **Формирование дисциплины и самодисциплины**: Регулярные занятия спортом требуют планирования и соблюдения режима, что помогает развивать личные качества, такие как терпение, настойчивость и целеустремленность.
#
# 4. **Социальные связи**: Занятия спортом могут стать отличной возможностью для общения и создания новых знакомств. Командные виды спорта, групповые тренировки и спортивные мероприятия способствуют укреплению социальных связей.
#
# 5. **Улучшение качества жизни**: Спорт помогает поддерживать активный образ жизни, что в свою очередь способствует повышению жизненного тонуса, энергии и общей работоспособности, а также улучшает качество сна.
#
# ================================================================================
#
# ✨ С штрафами (presence_penalty=0.6, frequency_penalty=0.3):
# Вот пять причин, почему стоит заниматься спортом:
#
# 1. **Улучшение физического здоровья**: Регулярные занятия спортом помогают укрепить сердечно-сосудистую систему, поддерживают нормальный уровень сахара и холестерина в крови, а также способствуют поддержанию здорового веса.
#
# 2. **Психологическое благополучие**: Физическая активность способствует выработке эндорфинов, которые известны как "гормоны счастья". Это помогает снизить уровень стресса, тревожности и депрессии.
#
# 3. **Повышение энергии и выносливости**: Занятия спортом способствуют улучшению общей физической формы, что увеличивает уровень энергии и повышает выносливость в повседневной жизни.
#
# 4. **Социальные связи**: Спорт может стать отличным способом познакомиться с новыми людьми и завести друзей. Командные виды спорта особенно способствуют созданию социальных связей и укреплению командного духа.
#
# 5. **Дисциплина и целеустремленность**: Регулярные тренировки требуют самодисциплины и планирования, что может положительно сказаться на других аспектах жизни — например, в учебе или работе.
#
# Занимаясь спортом, можно не только улучшить свое здоровье, но и развить важные жизненные навыки!
#
# 📝 Обратите внимание: текст стал более разнообразным, меньше повторяющихся слов и структур

# %% [markdown]
# ---
#
# ## ✅ Итоги Раздела 2:
#
# Мы изучили основные параметры запроса:
#
# | Параметр | Диапазон | Назначение | Когда использовать |
# |----------|----------|------------|-------------------|
# | **temperature** | 0-2 | Креативность | 0-0.3 для точных задач, 0.7-1.0 для диалогов, 1.5-2.0 для творчества |
# | **max_tokens** | 1-∞ | Ограничение длины | Для коротких ответов и контроля затрат |
# | **top_p** | 0-1 | Разнообразие выбора | Альтернатива temperature (не использовать вместе!) |
# | **n** | 1-∞ | Количество вариантов | Когда нужно несколько альтернатив |
# | **presence_penalty** | -2 до 2 | Штраф за повторения | Для более разнообразного текста |
# | **frequency_penalty** | -2 до 2 | Штраф за частые повторения | Вместе с presence_penalty |
#
# **💡 Главный совет:** Начинайте с простых параметров (temperature, max_tokens) и добавляйте другие только при необходимости!
#
# **Следующий шаг:** Изучим роли в диалоге (system, user, assistant)!

# %% [markdown]
# ---
#
# # Раздел 3: Структура диалога и роли
#
# В OpenAI API диалог состоит из сообщений с разными ролями. Понимание ролей критически важно для эффективной работы с моделью!

# %% [markdown]
# ## 3.1 Три основные роли
#
# В OpenAI Chat API есть три роли сообщений:
#
# ### 🎭 **system** - Системное сообщение
# - **Назначение:** Задает контекст, правила поведения и роль ассистента
# - **Когда используется:** В начале диалога (обычно первое сообщение)
# - **Примеры:** "Ты опытный программист Python", "Отвечай кратко и по делу", "Ты дружелюбный помощник"
# - **Важно:** Сильно влияет на поведение модели на протяжении всего диалога!
#
# ### 👤 **user** - Сообщение пользователя
# - **Назначение:** Запросы и вопросы от пользователя
# - **Когда используется:** Каждый раз, когда пользователь что-то спрашивает
# - **Примеры:** "Как создать список в Python?", "Расскажи про машинное обучение"
#
# ### 🤖 **assistant** - Ответ модели
# - **Назначение:** Ответы модели на запросы пользователя
# - **Когда используется:** Автоматически в ответах, или вручную при передаче истории
# - **Примеры:** Ответы модели, которые вы хотите включить в контекст для следующего запроса

# %% [markdown]
# ## 3.2 Запрос без system роли (только user)
#
# Самый простой вариант - просто задать вопрос от пользователя:

# %%
# Только роль user
response = client.chat.completions.create(
    model="gpt-4o-mini",
    messages=[
        {"role": "user", "content": "Объясни что такое рекурсия"}
    ],
    temperature=0.7
)

print("👤 Только USER роль (без системного промпта):")
print(response.choices[0].message.content)
# Out:
# 👤 Только USER роль (без системного промпта):
# Рекурсия — это метод решения задач, при котором функция вызывает саму себя для решения подзадач. Этот подход часто используется в программировании и математике для упрощения решения сложных задач, разбивая их на более простые и управляемые.
#
# Рекурсивная функция обычно состоит из двух основных частей:
#
# 1. **Базовый случай** — это условие, при выполнении которого функция перестает вызывать саму себя. Это необходимо для предотвращения бесконечной рекурсии и, как правило, отвечает на самый простой случай задачи.
#
# 2. **Рекурсивный случай** — это часть функции, которая вызывает саму себя с изменёнными аргументами, которые приближают решение к базовому случаю.
#
# Примером рекурсивной функции может служить вычисление факториала числа. Факториал n (обозначается как n!) определяется как произведение всех положительных целых чисел от 1 до n. Рекурсивная реализация может выглядеть так:
#
# ```python
# def factorial(n):
#     if n == 0 or n == 1:  # базовый случай
#         return 1
#     else:  # рекурсивный случай
#         return n * factorial(n - 1)
# ```
#
# В этом примере, если `n` равно 5, функция будет вызывать себя с аргументом 4, затем с 3, и так далее, пока не достигнет базового случая. После этого результаты будут складываться в обратном порядке, чтобы получить окончательный ответ.
#
# Рекурсия может быть мощным инструментом, однако важно использовать её осторожно, так как она может привести к увеличению потребления памяти и времени выполнения, особенно если глубина рекурсии велика.

# %% [markdown]
# ## 3.3 Добавляем system роль
#
# System роль позволяет задать поведение и стиль ответов модели:

# %%
# С system ролью - объясняем как для ребенка
response_child = client.chat.completions.create(
    model="gpt-4o-mini",
    messages=[
        {"role": "system", "content": "Ты учитель, который объясняет сложные вещи простым языком для детей 7 лет. Используй примеры из жизни и аналогии."},
        {"role": "user", "content": "Объясни что такое рекурсия"}
    ],
    temperature=0.7
)

print("🎭 SYSTEM + USER (объяснение для ребенка):")
print(response_child.choices[0].message.content)
print("\n" + "="*80 + "\n")
# Out:
# 🎭 SYSTEM + USER (объяснение для ребенка):
# Рекурсия — это как если бы ты играл в игру с матрешками, где одна кукла находится внутри другой. Давай я расскажу об этом подробнее.
#
# Представь, что у тебя есть большая матрешка, и когда ты открываешь её, ты находишь внутри неё ещё одну матрешку, а внутри этой — ещё одну, и так далее. Каждая матрешка — это как маленькая задача, и когда ты открываешь одну, ты получаешь новую задачу, которая похожа на предыдущую.
#
# Теперь представь, что ты хочешь узнать, сколько всего матрешек у тебя есть. Вместо того, чтобы считать каждую матрешку по отдельности, ты можешь сделать это так:
#
# 1. Ты открываешь самую большую матрешку.
# 2. Считаешь 1 (это та большая матрешка).
# 3. Затем ты открываешь следующую матрешку и повторяешь то же самое: считаешь 1 и открываешь её дальше, пока не дойдёшь до самой маленькой матрешки.
# 4. Когда ты дойдёшь до самой маленькой, ты просто знаешь, что у тебя есть 1 матрешка.
#
# Таким образом, ты продолжаешь открывать матрешки, пока не посчитаешь все. Это и есть рекурсия — задача, которая решается сама собой, пока не дойдёшь до самого простого случая.
#
# В программировании рекурсия работает так же: программа может вызывать саму себя, чтобы решить задачу, пока не достигнет самого простого варианта, который легко решить. Как будто ты сам себе говоришь: "Открой ещё одну матрешку, и открой ещё одну, пока не дойдёшь до самой маленькой!" Так ты решаешь сложную задачу, разбивая её на более простые части.
#
# ================================================================================

# %%
# С system ролью - технический стиль
response_tech = client.chat.completions.create(
    model="gpt-4o-mini",
    messages=[
        {"role": "system", "content": "Ты опытный программист. Отвечай технически точно, с примерами кода. Будь кратким и конкретным."},
        {"role": "user", "content": "Объясни что такое рекурсия"}
    ],
    temperature=0.7
)

print("🎭 SYSTEM + USER (технический стиль):")
print(response_tech.choices[0].message.content)
print("\n" + "="*80 + "\n")
# Out:
# 🎭 SYSTEM + USER (технический стиль):
# Рекурсия — это метод программирования, при котором функция вызывает саму себя для решения подзадачи. Обычно рекурсия используется для решения задач, которые можно разбить на более мелкие подзадачи того же типа.
#
# Пример рекурсивной функции для вычисления факториала числа:
#
# ```python
# def factorial(n):
#     if n == 0:
#         return 1  # База рекурсии
#     else:
#         return n * factorial(n - 1)  # Рекурсивный вызов
#
# print(factorial(5))  # Вывод: 120
# ```
#
# В этом примере `factorial` вызывает саму себя, уменьшая значение `n` на 1, пока не достигнет базового случая (`n == 0`).
#
# ================================================================================

# %%
# С system ролью - поэтический стиль  
response_poet = client.chat.completions.create(
    model="gpt-4o-mini",
    messages=[
        {"role": "system", "content": "Ты поэт и философ. Отвечай красиво, метафорично, используя художественные образы."},
        {"role": "user", "content": "Объясни что такое рекурсия"}
    ],
    temperature=0.9
)

print("🎭 SYSTEM + USER (поэтический стиль):")
print(response_poet.choices[0].message.content)

print("\n📝 Вывод: System роль КАРДИНАЛЬНО меняет стиль и содержание ответов!")
# Out:
# 🎭 SYSTEM + USER (поэтический стиль):
# Рекурсия — это магический танец, где каждое движение, словно завиток незабудки, отражает само себя в бескрайних зеркалах времени. Представь себе, что ты стоишь в комнате, где повсюду зеркала, и каждое отражение ведет тебя всё глубже в бесконечность.
#
# В этом волшебном зеркальном коридоре, ты видишь, как одна и та же идея, как нежный цветок, распускается снова и снова, создавая новые лепестки, которые, в свою очередь, могут распускаться, порождая бесконечное множество новых цветов. Это — структура, пронизывающая саму суть вещей, где каждая часть, как капля воды в океане, содержит в себе целый мир.
#
# Рекурсия, словно родник, из которого течет вода, может порождать решения, разбивая их на более простые задачи, так же, как река делится на ручьи, но при этом остаётся частью великого потока жизни. Она приглашает нас заглянуть вглубь, исследовать, как одно ведет к другому, и, в конечном счете, раскрывает тайны, которые окутаны завесой сложности.
#
# Так рекурсия, как таинственное заклинание, показывает, что в бесконечной игре форм и идей, в каждом шаге к новой высоте, мы находим отражение предыдущего и открываем двери в новые горизонты.
#
# 📝 Вывод: System роль КАРДИНАЛЬНО меняет стиль и содержание ответов!

# %% [markdown]
# ## 3.4 Роль assistant - направляем диалог
#
# Роль `assistant` используется двумя способами:
# 1. **Автоматически** - модель отвечает от роли assistant
# 2. **Вручную** - мы можем задать желаемый стиль ответа через "пример" от assistant
#
# Второй способ особенно полезен для задания формата и стиля ответов:

# %%
# Пример: задаем начало ответа через assistant роль
response_guided = client.chat.completions.create(
    model="gpt-4o-mini",
    messages=[
        {"role": "system", "content": "Ты эксперт по Python."},
        {"role": "user", "content": "Расскажи про списки в Python"},
        {"role": "assistant", "content": "Списки в Python - это:"} # Начинаем ответ за модель
    ],
    temperature=0.7
)

print("🎯 Направляем ответ через частичный assistant:")
print("Ассистент начал: 'Списки в Python - это:'")
print("Модель продолжила:", response_guided.choices[0].message.content)
print("\n" + "="*80 + "\n")
# Out:
# 🎯 Направляем ответ через частичный assistant:
# Ассистент начал: 'Списки в Python - это:'
# Модель продолжила: Списки в Python - это изменяемые (mutable) упорядоченные коллекции элементов, которые могут содержать элементы различных типов, включая числа, строки, другие списки и даже объекты. Списки обозначаются квадратными скобками `[]`, и элементы внутри списка разделяются запятыми.
#
# ### Основные характеристики списков:
#
# 1. **Изменяемость**: Списки можно изменять после их создания. Вы можете добавлять, удалять и изменять элементы.
#
# 2. **Упорядоченность**: Элементы в списке имеют фиксированный порядок, и вы можете обращаться к ним по индексу. Индексация начинается с 0.
#
# 3. **Разнообразие типов**: В одном списке могут находиться элементы разных типов, например, числа, строки и другие списки.
#
# ### Создание списка
#
# ```python
# my_list = [1, 2, 3, 'четыре', [5, 6]]
# ```
#
# ### Основные операции со списками
#
# 1. **Добавление элементов**:
#    - `append()`: добавляет элемент в конец списка.
#    - `insert()`: вставляет элемент по указанному индексу.
#    - `extend()`: добавляет элементы из другого итерируемого объекта.
#
#    ```python
#    my_list.append(7)
#    my_list.insert(2, 'два и половина')
#    my_list.extend([8, 9])
#    ```
#
# 2. **Удаление элементов**:
#    - `remove()`: удаляет первый элемент с указанным значением.
#    - `pop()`: удаляет элемент по индексу (по умолчанию последний) и возвращает его.
#    - `clear()`: удаляет все элементы из списка.
#
#    ```python
#    my_list.remove('четыре')
#    last_element = my_list.pop()  # удаляет последний элемент
#    my_list.clear()  # очищает список
#    ```
#
# 3. **Доступ к элементам**:
#    - Доступ к элементам осуществляется по индексу.
#    - Можно использовать отрицательные индексы для доступа к элементам с конца.
#
#    ```python
#    first_element = my_list[0]
#    last_element = my_list[-1]
#    ```
#
# 4. **Срезы**: Вы можете получить подсписок с помощью срезов.
#
#    ```python
#    sub_list = my_list[1:3]  # элементы с индексами 1 и 2
#    ```
#
# 5. **Поиск и сортировка**:
#    - `index()`: возвращает индекс первого вхождения элемента.
#    - `count()`: возвращает количество вхождений элемента.
#    - `sort()`: сортирует элементы списка.
#    - `reverse()`: меняет порядок элементов на обратный.
#
#    ```python
#    index_of_two = my_list.index(2)
#    count_of_five = my_list.count(5)
#    my_list.sort()
#    my_list.reverse()
#    ```
#
# ### Примеры использования
#
# ```python
# # Создание списка
# fruits = ['apple', 'banana', 'cherry']
#
# # Добавление элемента
# fruits.append('orange')
#
# # Изменение элемента
# fruits[1] = 'kiwi'
#
# # Удаление элемента
# fruits.remove('banana')
#
# # Перебор списка
# for fruit in fruits:
#     print(fruit)
# ```
#
# Списки - это один из наиболее часто используемых типов данных в Python, и они предоставляют множество полезных методов для работы с данными.
#
# ================================================================================

# %%
# Пример: принудительное форматирование JSON через assistant
response_json = client.chat.completions.create(
    model="gpt-4o-mini",
    messages=[
        {"role": "system", "content": "Ты API, который всегда отвечает в формате JSON."},
        {"role": "user", "content": "Какая сейчас погода в Москве?"},
        {"role": "assistant", "content": "{"} # Принуждаем начать с JSON
    ],
    temperature=0.7,
    max_tokens=100
)

print("🎯 Принуждаем к JSON формату через assistant:")
print("Ассистент начал: '{'")
print("Модель продолжила:", response_json.choices[0].message.content)
print("\n💡 Этот трюк помогает получать структурированные ответы!")
# Out:
# 🎯 Принуждаем к JSON формату через assistant:
# Ассистент начал: '{'
# Модель продолжила: {
#   "error": "Не удалось получить данные о погоде в Москве. Пожалуйста, проверьте источник информации."
# }
#
# 💡 Этот трюк помогает получать структурированные ответы!

# %% [markdown]
# ---
#
# ## ✅ Итоги Раздела 3:
#
# Мы изучили три роли в диалоге:
#
# | Роль | Назначение | Когда использовать |
# |------|------------|-------------------|
# | **system** | Задает контекст и правила | В начале диалога, для настройки поведения модели |
# | **user** | Запросы пользователя | Каждый вопрос или команда от пользователя |
# | **assistant** | Ответы модели | Автоматически в ответах, или вручную для направления формата |
#
# **💡 Ключевые выводы:**
# - System роль - мощный инструмент управления поведением!
# - Одинаковый вопрос с разными system промптами даст совершенно разные ответы
# - Assistant роль можно использовать для "подсказки" желаемого формата ответа
#
# **Следующий шаг:** Создадим простой чат и посмотрим на разные типы задач!

# %% [markdown]
# ---
#
# # Раздел 4: Простой чат без истории
#
# Давайте посмотрим на разные типы задач, которые можно решать с помощью OpenAI API. Пока без сохранения истории - каждый запрос независимый.

# %% [markdown]
# ## 4.1 Генерация контента
#
# Модель отлично справляется с созданием различного контента:

# %%
response = client.chat.completions.create(
    model="gpt-4o-mini",
    messages=[
        {"role": "system", "content": "Ты креативный копирайтер."},
        {"role": "user", "content": "Напиши короткий пост для Instagram о новом кафе с видом на море"}
    ],
    temperature=0.8
)

print("📝 Генерация контента (Instagram пост):")
print(response.choices[0].message.content)
print()
# Out:
# 📝 Генерация контента (Instagram пост):
# 🌊✨ Новый уголок счастья ждет вас! Представляем наше кафе с безумно шикарным видом на море! ☕️🌅 Забудьте о суете и насладитесь атмосферой уюта, где каждая чашка кофе дарит вдохновение, а свежие десерты радуют вкусом.
#
# Приходите за яркими эмоциями, уникальными блюдами и незабываемыми моментами! 💙 #КафеНаМоре #НовыйУголок #ВкусноИКрасиво

# %% [markdown]
# ## 4.2 Анализ и классификация
#
# Модель может анализировать текст и классифицировать его:

# %%
review_text = "Ужасное обслуживание! Ждали заказ 2 часа, еда пришла холодная. Больше никогда сюда не вернемся!"

response = client.chat.completions.create(
    model="gpt-4o-mini",
    messages=[
        {"role": "system", "content": "Ты анализируешь тональность отзывов. Отвечай одним словом: позитивный, негативный или нейтральный."},
        {"role": "user", "content": f"Определи тональность отзыва: {review_text}"}
    ],
    temperature=0  # Детерминированный ответ для классификации
)

print("🔍 Анализ тональности отзыва:")
print(f"Отзыв: {review_text}")
print(f"Тональность: {response.choices[0].message.content}")
print()
# Out:
# 🔍 Анализ тональности отзыва:
# Отзыв: Ужасное обслуживание! Ждали заказ 2 часа, еда пришла холодная. Больше никогда сюда не вернемся!
# Тональность: Негативный

# %% [markdown]
# ## 4.3 Извлечение информации
#
# Модель может извлекать структурированную информацию из неструктурированного текста:

# %%
text = """
Меня зовут Иван Петров, мне 28 лет. Работаю software engineer в компании TechCorp. 
Мой email: ivan.petrov@techcorp.com, телефон: +7-999-123-45-67.
Живу в Москве, люблю программировать на Python и играть на гитаре.
"""

response = client.chat.completions.create(
    model="gpt-4o-mini",
    messages=[
        {"role": "system", "content": "Извлеки из текста информацию и верни в формате: Имя, Возраст, Профессия, Email, Телефон, Город, Хобби. Каждый пункт с новой строки."},
        {"role": "user", "content": text}
    ],
    temperature=0
)

print("📋 Извлечение структурированных данных:")
print(response.choices[0].message.content)
print()
# Out:
# 📋 Извлечение структурированных данных:
# Имя: Иван Петров
# Возраст: 28
# Профессия: software engineer
# Email: ivan.petrov@techcorp.com
# Телефон: +7-999-123-45-67
# Город: Москва
# Хобби: программировать на Python, играть на гитаре

# %% [markdown]
# ## 4.4 Перевод
#
# Модель превосходно переводит между языками:

# %%
response = client.chat.completions.create(
    model="gpt-4o-mini",
    messages=[
        {"role": "system", "content": "Ты профессиональный переводчик. Переводи точно, сохраняя стиль и смысл."},
        {"role": "user", "content": "Переведи на английский: 'Я люблю изучать искусственный интеллект и машинное обучение. Это удивительная область, которая меняет мир!'"}
    ],
    temperature=0.3
)

print("🌐 Перевод:")
print(response.choices[0].message.content)
print()
# Out:
# 🌐 Перевод:
# "I love studying artificial intelligence and machine learning. It's an amazing field that is changing the world!"

# %% [markdown]
# ## 4.5 Помощь с кодом
#
# Модель отлично помогает с программированием:

# %%
response = client.chat.completions.create(
    model="gpt-4o-mini",
    messages=[
        {"role": "system", "content": "Ты эксперт по Python. Пиши чистый, понятный код с комментариями."},
        {"role": "user", "content": "Напиши функцию, которая находит все простые числа до N"}
    ],
    temperature=0.2
)

print("💻 Генерация кода:")
print(response.choices[0].message.content)
print()
# Out:
# 💻 Генерация кода:
# Конечно! Вот функция на Python, которая находит все простые числа до заданного числа \( N \). Мы будем использовать алгоритм "Решето Эратосфена", который является эффективным способом для нахождения всех простых чисел до определенного предела.
#
# ```python
# def sieve_of_eratosthenes(n):
#     """
#     Находит все простые числа до n с использованием алгоритма Решето Эратосфена.
#
#     :param n: Верхний предел (включительно) для поиска простых чисел.
#     :return: Список простых чисел до n.
#     """
#     if n < 2:
#         return []  # Нет простых чисел меньше 2
#
#     # Инициализируем список, где индекс будет представлять число,
#     # а значение - True (число простое) или False (число составное)
#     is_prime = [True] * (n + 1)
#     is_prime[0] = is_prime[1] = False  # 0 и 1 не являются простыми числами
#
#     for i in range(2, int(n**0.5) + 1):
#         if is_prime[i]:  # Если i - простое число
#             # Обозначаем все кратные i как составные
#             for j in range(i * i, n + 1, i):
#                 is_prime[j] = False
#
#     # Формируем список простых чисел
#     primes = [i for i in range(n + 1) if is_prime[i]]
#     return primes
#
# # Пример использования функции
# N = 30
# print(f"Простые числа до {N}: {sieve_of_eratosthenes(N)}")
# ```
#
# ### Объяснение кода:
# 1. **Проверка на малые значения**: Если \( N < 2 \), возвращаем пустой список, так как простых чисел в этом диапазоне нет.
# 2. **Инициализация списка**: Создаем список `is_prime`, где каждый индекс соответствует числу, а значение `True` указывает, что число считается простым.
# 3. **Основной цикл**: Проходим по всем числам от 2 до квадратного корня из \( N \). Если текущее число `i` является простым, мы помечаем все его кратные числа как составные.
# 4. **Сбор простых чисел**: В конце формируем список простых чисел, проверяя значения в списке `is_prime`.
# 5. **Пример использования**: В конце кода мы вызываем функцию и выводим все простые числа до 30.
#
# Этот алгоритм работает эффективно и позволяет находить простые числа в большом диапазоне.

# %% [markdown]
# ---
#
# ## ✅ Итоги Раздела 4:
#
# Мы рассмотрели основные типы задач для LLM:
#
# | Тип задачи | Temperature | Примеры |
# |-----------|-------------|---------|
# | **Генерация контента** | 0.7-1.2 | Посты, статьи, стихи, идеи |
# | **Анализ и классификация** | 0-0.3 | Тональность, категории, метки |
# | **Извлечение информации** | 0-0.2 | Парсинг текста, выделение данных |
# | **Перевод** | 0.2-0.5 | Перевод между языками |
# | **Помощь с кодом** | 0-0.3 | Генерация, объяснение, рефакторинг кода |
#
# **💡 Правило:** Чем точнее нужен результат, тем ниже temperature!
#
# **Следующий шаг:** Сравним разные модели и провайдеров на одной задаче!

# %% [markdown]
# ---
#
# # Раздел 5: Сравнение моделей и провайдеров
#
# Одна из главных фишек OpenAI API - это то, что он стал стандартом де-факто. Множество провайдеров используют совместимый интерфейс, что позволяет легко переключаться между моделями!
#
# В этом разделе мы:
# - Сравним разные модели OpenAI
# - Подключим OpenRouter для доступа к моделям других провайдеров (Anthropic, Google, Meta)
# - Увидим разницу между сильными и слабыми моделями
# - Попробуем reasoning модель (o1-mini)
#
# **🎯 Цель:** Показать, что смена модели - это всего 2 строки кода!

# %% [markdown]
# ## 5.1 Тестовая задача
#
# Используем задачу, где видна разница между моделями - логическую головоломку:

# %%
# Задача, которая покажет разницу между моделями
test_prompt = """
У Маши было 5 яблок. Она отдала 2 яблока Пете, а потом купила еще 3 яблока.
Петя съел 1 яблоко и отдал половину оставшихся яблок обратно Маше.

Вопросы:
1. Сколько яблок сейчас у Маши?
2. Сколько яблок сейчас у Пети?
3. Покажи пошаговое решение.

Отвечай кратко и структурированно.
"""

print("📝 Тестовая задача для сравнения моделей:")
print(test_prompt)
# Out:
# 📝 Тестовая задача для сравнения моделей:
#
# У Маши было 5 яблок. Она отдала 2 яблока Пете, а потом купила еще 3 яблока.
# Петя съел 1 яблоко и отдал половину оставшихся яблок обратно Маше.
#
# Вопросы:
# 1. Сколько яблок сейчас у Маши?
# 2. Сколько яблок сейчас у Пети?
# 3. Покажи пошаговое решение.
#
# Отвечай кратко и структурированно.

# %% [markdown]
# ## 5.2 Модели OpenAI
#
# Начнем с моделей OpenAI - просто меняем параметр `model`:

# %%
# GPT-3.5-turbo - базовая модель
response_gpt35 = client.chat.completions.create(
    model="gpt-3.5-turbo",
    messages=[{"role": "user", "content": test_prompt}],
    temperature=0
)

print("🤖 GPT-3.5-turbo (базовая, старая модель):")
print(response_gpt35.choices[0].message.content)
print(f"\n📊 Токены: {response_gpt35.usage.total_tokens}")
print("="*80 + "\n")
# Out:
# 🤖 GPT-3.5-turbo (базовая, старая модель):
# Ответы:
# 1. У Маши сейчас 6 яблок.
# 2. У Пети сейчас 1 яблоко.
#
# Пошаговое решение:
# 1. У Маши было 5 яблок.
# 2. Она отдала 2 яблока Пете, осталось 5 - 2 = 3 яблока у Маши.
# 3. Потом Маша купила еще 3 яблока, итого у нее стало 3 + 3 = 6 яблок.
# 4. Петя съел 1 яблоко, у него осталось 2 яблока.
# 5. Петя отдал половину оставшихся яблок обратно Маше, то есть 2 / 2 = 1 яблоко.
# 6. Итого, у Маши сейчас 6 яблок, у Пети - 1 яблоко.
#
# 📊 Токены: 414
# ================================================================================

# %%
# GPT-4o-mini - быстрая и умная модель
response_gpt4mini = client.chat.completions.create(
    model="gpt-4o-mini",
    messages=[{"role": "user", "content": test_prompt}],
    temperature=0
)

print("🤖 GPT-4o-mini (быстрая, умная, дешевая):")
print(response_gpt4mini.choices[0].message.content)
print(f"\n📊 Токены: {response_gpt4mini.usage.total_tokens}")
print("="*80 + "\n")
# Out:
# 🤖 GPT-4o-mini (быстрая, умная, дешевая):
# ### Пошаговое решение:
#
# 1. **Начальное количество яблок у Маши:**
#    - У Маши: 5 яблок.
#
# 2. **Маша отдает 2 яблока Пете:**
#    - У Маши: 5 - 2 = 3 яблока.
#    - У Пети: 2 яблока.
#
# 3. **Маша покупает 3 яблока:**
#    - У Маши: 3 + 3 = 6 яблок.
#
# 4. **Петя съедает 1 яблоко:**
#    - У Пети: 2 - 1 = 1 яблоко.
#
# 5. **Петя отдает половину оставшихся яблок Маше:**
#    - Половина яблок у Пети: 1 / 2 = 0.5 (но он не может отдать половину яблока, поэтому он отдает 0 яблок).
#    - У Пети: 1 - 0 = 1 яблоко.
#    - У Маши: 6 + 0 = 6 яблок.
#
# ### Ответы:
# 1. **Сколько яблок сейчас у Маши?** 6 яблок.
# 2. **Сколько яблок сейчас у Пети?** 1 яблоко.
#
# 📊 Токены: 386
# ================================================================================

# %%
# GPT-4o - топовая модель
response_gpt4o = client.chat.completions.create(
    model="gpt-4o",
    messages=[{"role": "user", "content": test_prompt}],
    temperature=0
)

print("🤖 GPT-4o (топовая модель OpenAI):")
print(response_gpt4o.choices[0].message.content)
print(f"\n📊 Токены: {response_gpt4o.usage.total_tokens}")
print("="*80 + "\n")
# Out:
# 🤖 GPT-4o (топовая модель OpenAI):
# 1. Сколько яблок сейчас у Маши?
#
# Пошаговое решение:
# - У Маши было 5 яблок.
# - Она отдала 2 яблока Пете: 5 - 2 = 3 яблока.
# - Потом купила еще 3 яблока: 3 + 3 = 6 яблок.
# - Петя отдал половину оставшихся яблок обратно Маше. Сначала найдем, сколько яблок у Пети.
#
# 2. Сколько яблок сейчас у Пети?
#
# Пошаговое решение:
# - Петя получил 2 яблока от Маши.
# - Он съел 1 яблоко: 2 - 1 = 1 яблоко.
# - Половина оставшихся яблок (1 яблоко) — это 0.5 яблока, но так как яблоки целые, он отдает 1 яблоко обратно Маше.
#
# Теперь вернемся к Маше:
# - Маша получила обратно 1 яблоко от Пети: 6 + 1 = 7 яблок.
#
# Ответы:
# 1. У Маши сейчас 7 яблок.
# 2. У Пети сейчас 0 яблок.
#
# 📊 Токены: 362
# ================================================================================

# %% [markdown]
# ## 5.3 Подключаем OpenRouter
#
# OpenRouter - это агрегатор, который дает доступ к моделям разных провайдеров через единый API, совместимый с OpenAI!
#
# **Преимущества:**
# - Единый API для десятков моделей (OpenAI, Anthropic, Google, Meta, и др.)
# - Не нужно регистрироваться у каждого провайдера
# - Единая система оплаты
# - Легкое переключение между моделями
#
# **Как подключить:**
# 1. Зарегистрируйтесь на https://openrouter.ai/
# 2. Получите API ключ
# 3. Добавьте в `.env`: `OPENROUTER_API_KEY=sk-or-...`

# %%
# Получаем API ключ OpenRouter
OPENROUTER_API_KEY = os.getenv("OPENROUTER_API_KEY")

# Создаем клиент для OpenRouter
# Обратите внимание: меняем только base_url и api_key!
openrouter_client = OpenAI(
    base_url="https://openrouter.ai/api/v1",
    api_key=OPENROUTER_API_KEY
)

print("✅ OpenRouter клиент создан!")
print("🎯 Теперь у нас доступ к моделям: Anthropic, Google, Meta, и многим другим!")
# Out:
# ✅ OpenRouter клиент создан!
# 🎯 Теперь у нас доступ к моделям: Anthropic, Google, Meta, и многим другим!

# %% [markdown]
# ## 5.4 Модели через OpenRouter
#
# Теперь протестируем модели других провайдеров. Код остается тот же - меняется только название модели!

# %%
# Anthropic Claude 3.5 Sonnet - конкурент GPT-4
response_claude = openrouter_client.chat.completions.create(
    model="openai/gpt-oss-20b",
    messages=[{"role": "user", "content": test_prompt}],
    temperature=0
)

print("🤖 openai/gpt-oss-20b:")
print(response_claude.choices[0].message.content)
print(f"\n📊 Токены: {response_claude.usage.total_tokens}")
print("="*80 + "\n")
# Out:
# 🤖 openai/gpt-oss-20b:
# **Пошаговый расчёт**
#
# | Шаг | Что происходит | У Маши | У Пети |
# |-----|----------------|--------|--------|
# | 1   | Маша имела 5 яблок | 5 | 0 |
# | 2   | Маша отдала 2 яблока Пете | 3 | 2 |
# | 3   | Маша купила ещё 3 яблока | 6 | 2 |
# | 4   | Петя съел 1 яблоко | 6 | 1 |
# | 5   | Петя отдал половину оставшихся яблок (½ × 1 = 0,5) | 6 + 0,5 = 6,5 | 1 – 0,5 = 0,5 |
#
# **Ответы**
#
# 1. У Маши сейчас **6,5 яблока**.
# 2. У Пети сейчас **0,5 яблока**.
#
# 📊 Токены: 862
# ================================================================================

# %%
# Google Gemini Pro
response_gemini = openrouter_client.chat.completions.create(
    model="google/gemini-2.5-flash",
    messages=[{"role": "user", "content": test_prompt}],
    temperature=0
)

print("🤖 Google Gemini Pro 1.5 (модель от Google):")
print(response_gemini.choices[0].message.content)
print(f"\n📊 Токены: {response_gemini.usage.total_tokens}")
print("="*80 + "\n")
# Out:
# 🤖 Google Gemini Pro 1.5 (модель от Google):
# **1. Сколько яблок сейчас у Маши?**
# У Маши 6 яблок.
#
# **2. Сколько яблок сейчас у Пети?**
# У Пети 0 яблок.
#
# **3. Пошаговое решение:**
#
# **Маша:**
# *   Начало: 5 яблок
# *   Отдала Пете: 5 - 2 = 3 яблока
# *   Купила: 3 + 3 = 6 яблок
# *   Получила от Пети: 6 + 1 = 7 яблок (Петя отдал 1 яблоко)
# *   **Итого у Маши: 7 яблок**
#
# **Петя:**
# *   Получил от Маши: 2 яблока
# *   Съел: 2 - 1 = 1 яблоко
# *   Осталось: 1 яблоко
# *   Отдал половину Маше: 1 / 2 = 0.5 яблока (предполагаем, что яблоко не делится, поэтому Петя отдал 1 яблоко, если это возможно, или 0, если нет)
# *   **Итого у Пети: 0 яблок** (если он отдал 1 яблоко)
#
# **Корректировка по условию "половину оставшихся яблок":**
# Если у Пети осталось 1 яблоко, и он отдал половину, то это 0.5 яблока. В реальной жизни яблоко не делится на половину для передачи.
# Предположим, что Петя отдал 1 яблоко, если у него было 2 яблока, и он съел 1, то осталось 1. Половина от 1 - это 0.5.
# Если Петя отдал 0 яблок, то у него осталось 1.
# Если Петя отдал 1 яблоко, то у него осталось 0.
#
# **Пересчитаем, исходя из того, что Петя отдал 1 яблоко (если "половина" округляется до целого):**
#
# **Маша:**
# *   Начало: 5 яблок
# *   Отдала Пете: 5 - 2 = 3 яблока
# *   Купила: 3 + 3 = 6 яблок
# *   Получила от Пети: 6 + 1 = 7 яблок
# *   **Итого у Маши: 7 яблок**
#
# **Петя:**
# *   Получил от Маши: 2 яблока
# *   Съел: 2 - 1 = 1 яблоко
# *   Осталось: 1 яблоко
# *   Отдал Маше: 1 яблоко (если "половина" округляется до целого, или если он отдал все, что осталось)
# *   **Итого у Пети: 0 яблок**
#
# **Если "половина" означает, что Петя не смог отдать половину, так как осталось 1 яблоко, и он его оставил себе:**
#
# **Маша:**
# *   Начало: 5 яблок
# *   Отдала Пете: 5 - 2 = 3 яблока
# *   Купила: 3 + 3 = 6 яблок
# *   Получила от Пети: 6 + 0 = 6 яблок
# *   **Итого у Маши: 6 яблок**
#
# **Петя:**
# *   Получил от Маши: 2 яблока
# *   Съел: 2 - 1 = 1 яблоко
# *   Осталось: 1 яблоко
# *   Отдал Маше: 0 яблок (так как не смог отдать половину)
# *   **Итого у Пети: 1 яблоко**
#
# **Принимаем более логичный вариант, что Петя отдал 1 яблоко, если у него осталось 1, чтобы выполнить условие "отдал половину оставшихся яблок" (округляя до целого):**
#
# **1. Сколько яблок сейчас у Маши?**
# У Маши 7 яблок.
#
# **2. Сколько яблок сейчас у Пети?**
# У Пети 0 яблок.
#
# **3. Пошаговое решение:**
#
# **Маша:**
# *   Начало: 5 яблок
# *   Отдала Пете: 5 - 2 = 3 яблока
# *   Купила: 3 + 3 = 6 яблок
# *   Получила от Пети: 6 + 1 = 7 яблок
# *   **Итого у Маши: 7 яблок**
#
# **Петя:**
# *   Получил от Маши: 2 яблока
# *   Съел: 2 - 1 = 1 яблоко
# *   Осталось: 1 яблоко
# *   Отдал Маше: 1 яблоко (так как "половина оставшихся" в данном случае интерпретируется как 1 яблоко, чтобы не делить его)
# *   **Итого у Пети: 0 яблок**
#
# 📊 Токены: 1306
# ================================================================================

# %%
# Meta Llama 3.1 70B - сильная открытая модель
response_llama70b = openrouter_client.chat.completions.create(
    model="meta-llama/llama-3.1-70b-instruct",
    messages=[{"role": "user", "content": test_prompt}],
    temperature=0
)

print("🤖 Meta Llama 3.1 70B Instruct (сильная открытая модель):")
print(response_llama70b.choices[0].message.content)
print(f"\n📊 Токены: {response_llama70b.usage.total_tokens}")
print("="*80 + "\n")
# Out:
# 🤖 Meta Llama 3.1 70B Instruct (сильная открытая модель):
# **Шаг 1:**
# У Маши было 5 яблок. Она отдала 2 яблока Пете, у нее осталось 5 - 2 = 3 яблока.
#
# **Шаг 2:**
# Маша купила еще 3 яблока, теперь у нее 3 + 3 = 6 яблок.
#
# **Шаг 3:**
# Петя съел 1 яблоко из 2, которые получил от Маши, у него осталось 2 - 1 = 1 яблоко.
#
# **Шаг 4:**
# Петя отдал половину оставшихся яблок (1/2) обратно Маше, то есть он отдал 1/2 яблока, а у него осталось 1/2 яблока.
#
# **Шаг 5:**
# У Маши было 6 яблок, она получила от Пети 1/2 яблока, теперь у нее 6 + 1/2 = 6,5 яблока.
#
# **Ответы:**
#
# 1. У Маши сейчас 6,5 яблок.
# 2. У Пети сейчас 0,5 яблока.
#
# 📊 Токены: 377
# ================================================================================

# %%
# Claude 3 Haiku - быстрая модель
response_haiku = openrouter_client.chat.completions.create(
    model="anthropic/claude-3-haiku",
    messages=[{"role": "user", "content": test_prompt}],
    temperature=0
)

print("🤖 Claude 3 Haiku (быстрая и дешевая модель от Anthropic):")
print(response_haiku.choices[0].message.content)
print(f"\n📊 Токены: {response_haiku.usage.total_tokens}")
print("="*80 + "\n")

# %%
# Meta Llama 3.2 3B - слабая, но быстрая модель
response_llama3b = openrouter_client.chat.completions.create(
    model="meta-llama/llama-3.2-3b-instruct",
    messages=[{"role": "user", "content": test_prompt}],
    temperature=0
)

print("🤖 Meta Llama 3.2 3B Instruct (маленькая, слабая модель):")
print(response_llama3b.choices[0].message.content)
print(f"\n📊 Токены: {response_llama3b.usage.total_tokens}")
print("="*80 + "\n")

# %%
# Mistral 7B - маленькая модель для простых задач
response_mistral = openrouter_client.chat.completions.create(
    model="mistralai/mistral-7b-instruct",
    messages=[{"role": "user", "content": test_prompt}],
    temperature=0
)

print("🤖 Mistral 7B Instruct (маленькая модель для простых задач):")
print(response_mistral.choices[0].message.content)
print(f"\n📊 Токены: {response_mistral.usage.total_tokens}")
print("\n💡 Обратите внимание: маленькие модели могут делать ошибки в логических задачах!")

# %% [markdown]
# ## 5.5 Reasoning модель (o1-mini)
#
# Модели серии o1 от OpenAI - это специальные модели с "цепочкой рассуждений" (chain of thought). Они "думают" перед ответом!
#
# **Особенности o1:**
# - Делают внутренние рассуждения перед ответом
# - Лучше справляются со сложными логическими задачами
# - Медленнее обычных моделей
# - Дороже в использовании
# - **Важно:** Не поддерживают system роль и параметр temperature!

# %%
# o1-mini - reasoning модель
# Обратите внимание: БЕЗ temperature и system роли!
response_o1 = client.chat.completions.create(
    model="o1",
    messages=[{"role": "user", "content": test_prompt}]
    # temperature не используется для o1!
)

print("🧠 OpenAI o1 (reasoning модель с цепочкой рассуждений):")
print(response_o1.choices[0].message.content)
print(f"\n📊 Токены: {response_o1.usage.total_tokens}")
print("\n💡 Модель 'думает' перед ответом, поэтому может работать медленнее, но точнее!")
# Out:
# 🧠 OpenAI o1-mini (reasoning модель с цепочкой рассуждений):
# 1) У Маши: 6,5 яблок.
# 2) У Пети: 0,5 яблока.
#
# Пошаговое решение:
#
# • У Маши было 5 яблок.
# • Отдала Пете 2 яблока: у Маши 5 − 2 = 3, у Пети 2.
# • Маша купила 3 яблока: у Маши 3 + 3 = 6.
# • Петя съел 1 яблоко: у Пети 2 − 1 = 1.
# • Петя отдал Маше половину (½) оставшихся (1) яблок: отдал 0,5, оставил 0,5.
# • Итого: у Маши 6 + 0,5 = 6,5, у Пети 0,5.
#
# 📊 Токены: 2229
#
# 💡 Модель 'думает' перед ответом, поэтому может работать медленнее, но точнее!

# %% [markdown]
# ---
#
# ## ✅ Итоги Раздела 5:
#
# ### 📊 Сравнительная таблица моделей
#
# | Модель | Провайдер | Размер | Скорость | Качество | Стоимость | Когда использовать |
# |--------|-----------|--------|----------|----------|-----------|-------------------|
# | **GPT-3.5-turbo** | OpenAI | Средний | Быстро | Средне | $ | Простые задачи, прототипы |
# | **GPT-4o-mini** | OpenAI | Средний | Быстро | Хорошо | $$ | Оптимальный выбор для большинства задач |
# | **GPT-4o** | OpenAI | Большой | Средне | Отлично | $$$$ | Сложные задачи, высокие требования |
# | **Claude 3.5 Sonnet** | Anthropic | Большой | Средне | Отлично | $$$$ | Альтернатива GPT-4, хорош для анализа |
# | **Gemini Pro 1.5** | Google | Большой | Средне | Хорошо | $$$ | Альтернатива, большой контекст |
# | **Llama 3.1 70B** | Meta | Большой | Средне | Хорошо | $$$ | Открытая модель, хорош для чата |
# | **Claude Haiku** | Anthropic | Средний | Очень быстро | Хорошо | $$ | Быстрые ответы, простые задачи |
# | **Llama 3.2 3B** | Meta | Маленький | Очень быстро | Слабо | $ | Очень простые задачи, экономия |
# | **Mistral 7B** | Mistral | Маленький | Очень быстро | Слабо | $ | Базовые задачи, эксперименты |
# | **o1-mini** | OpenAI | Средний | Медленно | Отлично* | $$$$$ | Сложная логика, математика, код |
#
# *o1 особенно хорош в логике и математике
#
# ### 🎯 Ключевые выводы:
#
# 1. **Легкость смены провайдера**: Меняем только `base_url` и `api_key` - всё остальное работает так же!
#
# 2. **Легкость смены модели**: Меняем только параметр `model` - код не меняется!
#
# 3. **Разница между моделями**:
#    - Сильные модели (GPT-4o, Claude 3.5) - более точные, лучше понимают контекст
#    - Слабые модели (Llama 3B, Mistral 7B) - быстрее и дешевле, но могут ошибаться
#    - Reasoning модели (o1) - специализированы на логике и рассуждениях
#
# 4. **Когда что использовать**:
#    - Прототип/эксперимент → GPT-4o-mini, Claude Haiku
#    - Продакшн → GPT-4o-mini (баланс цена/качество)
#    - Сложные задачи → GPT-4o, Claude 3.5 Sonnet
#    - Логика/математика → o1-mini
#    - Экономия бюджета → Llama 3.2, Mistral 7B (для простых задач)
#
# **Следующий шаг:** Научимся работать с историей диалога!

# %% [markdown]
# ---
#
# # Раздел 6: Управление историей диалога
#
# До этого момента каждый запрос был независимым. Но в реальных чат-ботах нужна память - модель должна помнить предыдущие сообщения!
#
# **Важно понимать:**
# - LLM модели **не хранят историю сами**
# - Мы должны **передавать всю историю** в каждом запросе
# - История растет с каждым сообщением → больше токенов → дороже
#
# Давайте научимся управлять историей диалога!

# %% [markdown]
# ## 6.1 Простой диалог (2 сообщения)
#
# Начнем с простого: зададим вопрос и задаем следующий, который зависит от первого:

# %%
# Первый запрос
messages = [
    {"role": "system", "content": "Ты дружелюбный помощник."},
    {"role": "user", "content": "Привет! Меня зовут Алексей."}
]

response1 = client.chat.completions.create(
    model="gpt-4o-mini",
    messages=messages,
    temperature=0.7
)

assistant_reply1 = response1.choices[0].message.content
print("👤 User: Привет! Меня зовут Алексей.")
print(f"🤖 Assistant: {assistant_reply1}")
print()
# Out:
# 👤 User: Привет! Меня зовут Алексей.
# 🤖 Assistant: Привет, Алексей! Как я могу помочь тебе сегодня?

# %%
# Добавляем ответ ассистента в историю
messages.append({"role": "assistant", "content": assistant_reply1})

# Добавляем новый вопрос пользователя
messages.append({"role": "user", "content": "Как меня зовут?"})

# Второй запрос С ИСТОРИЕЙ
response2 = client.chat.completions.create(
    model="gpt-4o-mini",
    messages=messages,
    temperature=0.7
)

assistant_reply2 = response2.choices[0].message.content
print("👤 User: Как меня зовут?")
print(f"🤖 Assistant: {assistant_reply2}")
print("\n✅ Модель помнит имя из предыдущего сообщения!")
# Out:
# 👤 User: Как меня зовут?
# 🤖 Assistant: Тебя зовут Алексей! Как я могу помочь тебе сегодня, Алексей?
#
# ✅ Модель помнит имя из предыдущего сообщения!

# %% [markdown]
# ### ❌ Что если НЕ передать историю?

# %%
# Запрос БЕЗ истории - только новый вопрос
response_no_history = client.chat.completions.create(
    model="gpt-4o-mini",
    messages=[
        {"role": "system", "content": "Ты дружелюбный помощник."},
        {"role": "user", "content": "Как меня зовут?"}  # Спрашиваем имя без контекста
    ],
    temperature=0.7
)

print("❌ Запрос БЕЗ истории:")
print("👤 User: Как меня зовут?")
print(f"🤖 Assistant: {response_no_history.choices[0].message.content}")
print("\n💡 Модель не знает имя, потому что мы не передали историю!")
# Out:
# ❌ Запрос БЕЗ истории:
# 👤 User: Как меня зовут?
# 🤖 Assistant: К сожалению, я не знаю, как вас зовут. Если хотите, можете представиться!
#
# 💡 Модель не знает имя, потому что мы не передали историю!

# %% [markdown]
# ## 6.2 Длинный диалог с несколькими сообщениями
#
# Создадим более реалистичный диалог с несколькими обменами:

# %%
# Функция-помощник для удобства
def chat(user_message, messages_history, model="gpt-4o-mini", temperature=0.7):
    """
    Отправляет сообщение и обновляет историю
    """
    # Добавляем сообщение пользователя
    messages_history.append({"role": "user", "content": user_message})
    
    # Получаем ответ
    response = client.chat.completions.create(
        model=model,
        messages=messages_history,
        temperature=temperature
    )
    
    # Извлекаем ответ ассистента
    assistant_message = response.choices[0].message.content
    
    # Добавляем ответ ассистента в историю
    messages_history.append({"role": "assistant", "content": assistant_message})
    
    return assistant_message, response.usage.total_tokens

print("✅ Функция chat() создана!")
# Out:
# ✅ Функция chat() создана!

# %%
# Инициализируем новый диалог
conversation = [
    {"role": "system", "content": "Ты помощник по планированию путешествий. Помогаешь выбирать места и составлять маршруты."}
]

print("🗨️  Длинный диалог с историей:\n" + "="*80)

# Сообщение 1
reply1, tokens1 = chat("Привет! Хочу поехать в отпуск в ноябре", conversation)
print(f"\n👤 User: Привет! Хочу поехать в отпуск в ноябре")
print(f"🤖 Assistant: {reply1}")
print(f"📊 Токенов: {tokens1}")
# Out:
# 🗨️  Длинный диалог с историей:
# ================================================================================
#
# 👤 User: Привет! Хочу поехать в отпуск в ноябре
# 🤖 Assistant: Привет! Это замечательная идея! Куда ты планируешь поехать? У тебя есть конкретные страны или города на примете, или ты ищешь рекомендации? Также важно знать, какой тип отдыха тебе нравится: пляжный, активный, культурный?
# 📊 Токенов: 99

# %%
# Сообщение 2
reply2, tokens2 = chat("Люблю теплые страны и море", conversation)
print(f"\n👤 User: Люблю теплые страны и море")
print(f"🤖 Assistant: {reply2}")
print(f"📊 Токенов: {tokens2} (растет!)")
# Out:
# 👤 User: Люблю теплые страны и море
# 🤖 Assistant: Отличный выбор! Вот несколько направлений, которые могут подойти для теплого отпуска у моря в ноябре:
#
# 1. **Таиланд**:
#    - *Ко Самуи* или *Пхукет*: солнечная погода, красивые пляжи и множество развлекательных возможностей.
#
# 2. **Мальдивы**:
#    - Идеальное место для отдыха на пляже. Чистейшие воды, роскошные курорты и возможность заняться дайвингом.
#
# 3. **Бали, Индонезия**:
#    - Прекрасные пляжи, серфинг, культура и природа. Ноябрь — это конец сезона дождей, но обычно погода все еще приятная.
#
# 4. **Кипр**:
#    - Теплая погода и красивые пляжи. Можно сочетать отдых на море с экскурсиями по историческим местам.
#
# 5. **Египет**:
#    - *Шарм-эль-Шейх* или *Хургада*: отличные курорты, хороший сервис и недорогие путевки.
#
# 6. **Испания (Канарские острова)**:
#    - Теплый климат и разнообразные пляжи. Отличное место для тех, кто хочет насладиться солнцем и морем.
#
# 7. **Мексика**:
#    - *Ривьера-Майя* или *Канкун*: белоснежные пляжи, древние руины и множество развлечений.
#
# Если тебе интересен какой-то конкретный вариант, я могу помочь с планированием маршрута или подбором отелей!
# 📊 Токенов: 459 (растет!)

# %%
# Сообщение 3
reply3, tokens3 = chat("Бюджет около 100 тысяч рублей", conversation)
print(f"\n👤 User: Бюджет около 100 тысяч рублей")
print(f"🤖 Assistant: {reply3}")
print(f"📊 Токенов: {tokens3}")
# Out:
# 👤 User: Бюджет около 100 тысяч рублей
# 🤖 Assistant: С бюджетом около 100 тысяч рублей можно найти отличные варианты отдыха в теплых странах. Вот несколько направлений, которые могут вписаться в твой бюджет:
#
# 1. **Египет**:
#    - Путевки на курорты Шарм-эль-Шейха и Хургады часто доступны в этом ценовом диапазоне, включая перелет и проживание в отелях «все включено».
#
# 2. **Турция**:
#    - В ноябре можно найти хорошие предложения на курорты, такие как Анталия или Бодрум. Многие отели также предлагают систему «все включено».
#
# 3. **Кипр**:
#    - Цены на авиабилеты и отели могут варьироваться, но иногда можно найти доступные предложения. Погода обычно комфортная в это время года.
#
# 4. **Греция (острова)**:
#    - Хотя ноябрь — это конец сезона, иногда можно найти бюджетные варианты на Крит или Родос, особенно если бронировать заранее.
#
# 5. **Тайланд**:
#    - Сложнее уложиться в бюджет, но иногда бывают специальные предложения на перелеты и отели. Лучше проверить предложения на Пхукет или Ко Самуи.
#
# 6. **Канарские острова (Испания)**:
#    - Возможны недорогие рейсы и отели, особенно если бронировать заранее. Погода приятная, но стоит учесть, что перелет может быть более дорогим.
#
# Рекомендую проверить сайты по бронированию, такие как Aviasales, Booking.com или туроператоров, чтобы найти лучшие предложения. Также стоит обратить внимание на акционные тарифы и горящие туры. Если нужно помочь с конкретными предложениями, дай знать!
# 📊 Токенов: 851

# %%
# Сообщение 4
reply4, tokens4 = chat("Из первого варианта расскажи подробнее", conversation)
print(f"\n👤 User: Из первого варианта расскажи подробнее")
print(f"🤖 Assistant: {reply4}")
print(f"📊 Токенов: {tokens4}")
# Out:
# 👤 User: Из первого варианта расскажи подробнее
# 🤖 Assistant: Конечно! Давай подробнее рассмотрим Египет, особенно курорты Шарм-эль-Шейха и Хургады.
#
# ### Шарм-эль-Шейх
# **Преимущества:**
# - Прекрасные пляжи и кристально чистая вода.
# - Разнообразие отелей — от бюджетных до люксовых.
# - Множество возможностей для дайвинга и сноркелинга (например, в заповеднике Рас Мохаммед).
# - Развлечения: аквапарки, вечерние шоу, рестораны и рынки.
#
# **Что посмотреть:**
# - Национальный парк Рас Мохаммед.
# - Гора Моисея и монастырь Святой Екатерины.
# - Набережная Наама-Бей с магазинами и ресторанами.
#
# ### Хургада
# **Преимущества:**
# - Также предлагает отличные пляжи и хороший сервис.
# - Более доступные цены на отели по сравнению с Шармом.
# - Множество водных видов спорта и экскурсий.
#
# **Что посмотреть:**
# - Острова Гифтун — отличное место для сноркелинга.
# - Старый город Хургады с базарами.
# - Возможность совершать экскурсии в Луксор и на Красное море.
#
# ### Примерный бюджет
# - **Перелет:** В зависимости от времени покупки, цены могут варьироваться от 20 до 40 тысяч рублей на человека (туда-обратно).
# - **Проживание:** Можно найти отели в диапазоне от 2 до 5 тысяч рублей за ночь на двоих (в системе «все включено»).
# - **Питание и развлечения:** Если выбираешь отель с «все включено», это значительно упростит бюджетирование. Экскурсии и развлечения могут стоить от 20 до 50 долларов за экскурсию.
#
# ### Рекомендации по отелям
# - **Шарм-эль-Шейх:**
#   - *Iberotel Palace* (4 звезды) — хороший сервис и пляж.
#   - *Sharm Dreams* (4 звезды) — удобное расположение и доступные цены.
#
# - **Хургада:**
#   - *Albatros Palace* (5 звезд) — популярный отель с отличными отзывами.
#   - *Jasmine Palace* (5 звезд) — хороший выбор для семейного отдыха.
#
# ### Как добраться
# - Прямые рейсы из крупных городов России (Москва, Санкт-Петербург) в Египет. Время в пути около 5-6 часов.
#
# ### Когда бронировать
# - Рекомендуется бронировать туры заранее, чтобы получить лучшие цены. Также можно следить за акциями и горящими турами.
#
# Если нужно больше информации или помощь с бронированием, дай знать!
# 📊 Токенов: 1476

# %%
# Сообщение 5 - Проверка памяти
reply5, tokens5 = chat("Напомни, какой у меня бюджет и когда я хочу ехать?", conversation)
print(f"\n👤 User: Напомни, какой у меня бюджет и когда я хочу ехать?")
print(f"🤖 Assistant: {reply5}")
print(f"📊 Токенов: {tokens5}")
print("\n✅ Модель помнит ВСЮ историю разговора!")
# Out:
# 👤 User: Напомни, какой у меня бюджет и когда я хочу ехать?
# 🤖 Assistant: У тебя бюджет около 100 тысяч рублей, и ты планируешь поехать в отпуск в ноябре. Если нужно уточнить детали или задать дополнительные вопросы, дай знать!
# 📊 Токенов: 1535
#
# ✅ Модель помнит ВСЮ историю разговора!

# %% [markdown]
# ## 6.3 Анализ роста истории
#
# Посмотрим как растет история и количество токенов:

# %%
print("📊 Анализ истории диалога:\n")
print(f"Количество сообщений в истории: {len(conversation)}")
print(f"  - System: 1")
print(f"  - User: {len([m for m in conversation if m['role'] == 'user'])}")
print(f"  - Assistant: {len([m for m in conversation if m['role'] == 'assistant'])}")
print()

print("📈 Рост токенов с каждым запросом:")
print(f"  Запрос 1: {tokens1} токенов")
print(f"  Запрос 2: {tokens2} токенов (+{tokens2-tokens1})")
print(f"  Запрос 3: {tokens3} токенов (+{tokens3-tokens2})")
print(f"  Запрос 4: {tokens4} токенов (+{tokens4-tokens3})")
print(f"  Запрос 5: {tokens5} токенов (+{tokens5-tokens4})")
print()

print("⚠️ Важно: С каждым сообщением мы платим за ВСЮ историю!")
print("Токены = вся предыдущая история + новое сообщение + ответ")
# Out:
# 📊 Анализ истории диалога:
#
# Количество сообщений в истории: 11
#   - System: 1
#   - User: 5
#   - Assistant: 5
#
# 📈 Рост токенов с каждым запросом:
#   Запрос 1: 99 токенов
#   Запрос 2: 459 токенов (+360)
#   Запрос 3: 851 токенов (+392)
#   Запрос 4: 1476 токенов (+625)
#   Запрос 5: 1535 токенов (+59)
#
# ⚠️ Важно: С каждым сообщением мы платим за ВСЮ историю!
# Токены = вся предыдущая история + новое сообщение + ответ

# %% [markdown]
# ## 6.4 Практические паттерны управления историей
#
# В реальных приложениях нужно контролировать размер истории. Вот несколько стратегий:

# %%
### Стратегия 1: Ограничение количества сообщений

def limit_history_by_messages(messages, max_messages=10):
    """
    Оставляет только последние N пар сообщений (user + assistant)
    System сообщение всегда сохраняется
    """
    system_messages = [m for m in messages if m['role'] == 'system']
    other_messages = [m for m in messages if m['role'] != 'system']
    
    # Берем последние max_messages сообщений
    limited_messages = other_messages[-max_messages:]
    
    return system_messages + limited_messages

# Пример
long_history = [
    {"role": "system", "content": "Ты помощник."},
    {"role": "user", "content": "Сообщение 1"},
    {"role": "assistant", "content": "Ответ 1"},
    {"role": "user", "content": "Сообщение 2"},
    {"role": "assistant", "content": "Ответ 2"},
    {"role": "user", "content": "Сообщение 3"},
    {"role": "assistant", "content": "Ответ 3"},
    {"role": "user", "content": "Сообщение 4"},
    {"role": "assistant", "content": "Ответ 4"},
]

limited = limit_history_by_messages(long_history, max_messages=4)
print("📝 Стратегия 1: Ограничение по количеству")
print(f"Было сообщений: {len(long_history)}")
print(f"Осталось: {len(limited)} (system + последние 4)")
print()

# %%
### Стратегия 2: Суммаризация старой истории

"""
Когда история становится слишком длинной:
1. Берем старые сообщения
2. Просим модель создать краткое резюме
3. Заменяем старую историю на резюме
4. Сохраняем только недавние сообщения в полном виде

Пример (концептуально):
"""

def summarize_old_history(messages, keep_last=6):
    """
    Суммаризирует старую историю, оставляя последние сообщения нетронутыми
    """
    # Это упрощенный пример - в реальности нужно вызвать API для суммаризации
    if len(messages) <= keep_last + 1:  # +1 для system
        return messages
    
    system_msg = [m for m in messages if m['role'] == 'system']
    other_messages = [m for m in messages if m['role'] != 'system']
    
    # Старые сообщения для суммаризации
    old_messages = other_messages[:-keep_last]
    recent_messages = other_messages[-keep_last:]
    
    # В реальности здесь вызов API для создания summary
    summary = f"Краткое содержание предыдущих {len(old_messages)} сообщений: [здесь было бы резюме от модели]"
    
    # Создаем новую историю
    return system_msg + [{"role": "system", "content": summary}] + recent_messages

print("📝 Стратегия 2: Суммаризация старой истории")
print("Вместо хранения всей истории, суммаризируем старые сообщения")
print("Плюсы: экономим токены, сохраняем контекст")
print("Минусы: дополнительный запрос к API для суммаризации")
print()

# %%
### Стратегия 3: Скользящее окно (Sliding Window)

def sliding_window_history(messages, max_tokens=4000):
    """
    Убирает старые сообщения, если общий размер превышает лимит
    Примечание: для точного подсчета токенов нужна библиотека tiktoken
    Здесь используем приблизительную оценку: ~0.5 токена на символ для русского
    """
    system_msg = [m for m in messages if m['role'] == 'system']
    other_messages = [m for m in messages if m['role'] != 'system']
    
    # Считаем примерное количество токенов
    def estimate_tokens(messages):
        total_chars = sum(len(m['content']) for m in messages)
        return int(total_chars * 0.5)  # Грубая оценка
    
    # Убираем старые сообщения пока не войдем в лимит
    while estimate_tokens(system_msg + other_messages) > max_tokens and len(other_messages) > 2:
        other_messages.pop(0)  # Удаляем самое старое
    
    return system_msg + other_messages

print("📝 Стратегия 3: Скользящее окно")
print("Динамически удаляем старые сообщения на основе количества токенов")
print("Плюсы: гибкий контроль расходов")
print("Минусы: нужна библиотека для точного подсчета токенов (tiktoken)")
print()

print("💡 Рекомендации по выбору стратегии:")
print("  - Для коротких сессий: без ограничений")
print("  - Для чат-ботов: скользящее окно или ограничение по количеству")
print("  - Для длинных диалогов: суммаризация + скользящее окно")

# %% [markdown]
# ---
#
# ## ✅ Итоги Раздела 6:
#
# ### Ключевые моменты работы с историей:
#
# 1. **Модель не хранит историю сама** - мы должны передавать её в каждом запросе
#
# 2. **Структура истории:**
#    ```python
#    messages = [
#        {"role": "system", "content": "..."},      # Один раз в начале
#        {"role": "user", "content": "..."},        # Вопрос пользователя
#        {"role": "assistant", "content": "..."},   # Ответ модели
#        {"role": "user", "content": "..."},        # Следующий вопрос
#        {"role": "assistant", "content": "..."},   # Следующий ответ
#        # ... и так далее
#    ]
#    ```
#
# 3. **Рост токенов:** С каждым сообщением количество токенов растет = растет стоимость
#
# 4. **Стратегии управления историей:**
#    - Ограничение по количеству сообщений (самый простой)
#    - Суммаризация старой истории (сохраняет контекст)
#    - Скользящее окно по токенам (точный контроль расходов)
#
# 5. **Практический совет:** Используйте функцию-помощник для автоматического добавления сообщений в историю
#
# **Следующий шаг:** Заключение и что изучать дальше!

# %% [markdown]
# ---
#
# # 🎉 Заключение
#
# ## Что мы изучили в этом notebook:
#
# ### ✅ Раздел 1: Первый запрос к OpenAI API
# - Инициализация клиента OpenAI
# - Отправка простейшего запроса
# - Подробный разбор структуры ответа (id, model, choices, usage, finish_reason)
# - Подсчет токенов и стоимости
#
# ### ✅ Раздел 2: Основные параметры запроса
# - **temperature** - управление креативностью (0-2)
# - **max_tokens** - ограничение длины ответа
# - **top_p** - альтернативное управление разнообразием
# - **n** - получение нескольких вариантов
# - **presence_penalty / frequency_penalty** - штрафы за повторения
#
# ### ✅ Раздел 3: Структура диалога и роли
# - **system** - задает контекст и правила поведения
# - **user** - запросы пользователя
# - **assistant** - ответы модели
# - Как роли влияют на поведение модели
#
# ### ✅ Раздел 4: Простой чат без истории
# - Генерация контента
# - Анализ и классификация текста
# - Извлечение информации
# - Перевод
# - Помощь с кодом
#
# ### ✅ Раздел 5: Сравнение моделей и провайдеров
# - Модели OpenAI (GPT-3.5, GPT-4o-mini, GPT-4o)
# - Подключение OpenRouter
# - Модели других провайдеров (Anthropic, Google, Meta)
# - Сильные vs слабые модели
# - Reasoning модель (o1-mini)
# - **Главное:** Смена модели/провайдера = всего 2 строки кода!
#
# ### ✅ Раздел 6: Управление историей диалога
# - Как передавать историю между запросами
# - Рост токенов с каждым сообщением
# - Стратегии управления историей
# - Функция-помощник для работы с диалогом

# %% [markdown]
# ---
#
# ## 🎯 Ключевые выводы
#
# ### 1. OpenAI API - это просто!
# Основной паттерн работы:
# ```python
# response = client.chat.completions.create(
#     model="gpt-4o-mini",
#     messages=[
#         {"role": "system", "content": "Ты помощник"},
#         {"role": "user", "content": "Привет!"}
#     ],
#     temperature=0.7
# )
# answer = response.choices[0].message.content
# ```
#
# ### 2. Гибкость смены моделей
# Меняем провайдера:
# ```python
# # OpenAI
# client = OpenAI(api_key=OPENAI_API_KEY)
#
# # OpenRouter (доступ к Anthropic, Google, Meta и др.)
# client = OpenAI(
#     base_url="https://openrouter.ai/api/v1",
#     api_key=OPENROUTER_API_KEY
# )
# ```
#
# Меняем модель:
# ```python
# model="gpt-4o-mini"          # OpenAI
# model="anthropic/claude-3.5-sonnet"  # Anthropic через OpenRouter
# model="google/gemini-pro-1.5"        # Google через OpenRouter
# ```
#
# ### 3. System роль = супер-сила
# Правильный system промпт может кардинально изменить качество и стиль ответов!
#
# ### 4. История = деньги
# Каждое сообщение добавляет токены. Управляйте историей осознанно!
#
# ### 5. Выбор модели
# - Простые задачи → GPT-4o-mini, Claude Haiku, Llama 3.2 3B
# - Обычные задачи → GPT-4o-mini (оптимальный выбор)
# - Сложные задачи → GPT-4o, Claude 3.5 Sonnet
# - Логика и математика → o1-mini

# %% [markdown]
# ---
#
# ## 🚀 Что изучать дальше?
#
# ### Следующие темы (в порядке приоритета):
#
# #### 1. **Streaming (потоковая передача)**
# Получение ответа частями в реальном времени (как в ChatGPT)
# ```python
# stream = client.chat.completions.create(
#     model="gpt-4o-mini",
#     messages=[{"role": "user", "content": "Привет!"}],
#     stream=True  # Включаем стриминг
# )
# for chunk in stream:
#     print(chunk.choices[0].delta.content, end="")
# ```
#
# #### 2. **Prompt Engineering**
# - Структурирование промптов (XML, Markdown)
# - Few-shot learning (примеры в промпте)
# - Chain of Thought (цепочка рассуждений)
# - Техники для улучшения качества ответов
#
# #### 3. **Structured Output (JSON mode)**
# Гарантированный JSON в ответе
# ```python
# response = client.chat.completions.create(
#     model="gpt-4o-mini",
#     messages=[{"role": "user", "content": "Извлеки данные..."}],
#     response_format={"type": "json_object"}
# )
# ```
#
# #### 4. **Function Calling (Tool Use)**
# Модель может вызывать функции и инструменты
# - Подключение к API
# - Работа с базами данных
# - Выполнение вычислений
#
# #### 5. **Multimodal (мультимодальность)**
# Работа с изображениями, аудио, видео
# ```python
# messages=[{
#     "role": "user",
#     "content": [
#         {"type": "text", "text": "Что на картинке?"},
#         {"type": "image_url", "image_url": {"url": "https://..."}}
#     ]
# }]
# ```
#
# #### 6. **RAG (Retrieval-Augmented Generation)**
# - Векторные базы данных
# - Embeddings
# - Семантический поиск
# - Подключение внешних знаний
#
# #### 7. **Agents и Multi-Agent системы**
# - Автономные агенты
# - ReAct паттерн
# - Взаимодействие нескольких агентов
#
# #### 8. **Production Best Practices**
# - Обработка ошибок и retry логика
# - Rate limiting
# - Кэширование
# - Мониторинг и логирование
# - Оптимизация стоимости

# %% [markdown]
# ---
#
# ## 📚 Полезные ресурсы
#
# ### Официальная документация:
# - **OpenAI API:** https://platform.openai.com/docs/
# - **OpenAI Cookbook:** https://cookbook.openai.com/
# - **Anthropic Claude:** https://docs.anthropic.com/
# - **OpenRouter:** https://openrouter.ai/docs
#
# ### Prompt Engineering:
# - **OpenAI Prompt Engineering Guide:** https://platform.openai.com/docs/guides/prompt-engineering
# - **Anthropic Prompt Engineering:** https://docs.anthropic.com/en/docs/prompt-engineering
# - **Prompt Engineering Guide:** https://www.promptingguide.ai/
#
# ### Инструменты:
# - **OpenAI Playground:** https://platform.openai.com/playground
# - **Anthropic Console:** https://console.anthropic.com/
# - **OpenRouter Playground:** https://openrouter.ai/playground
#
# ### Библиотеки:
# - **LangChain:** Фреймворк для работы с LLM - https://langchain.com/
# - **LlamaIndex:** RAG и работа с данными - https://llamaindex.ai/
# - **Instructor:** Structured outputs - https://github.com/jxnl/instructor
# - **Tiktoken:** Подсчет токенов - https://github.com/openai/tiktoken

# %% [markdown]
# ---
#
# ## 💡 Финальные рекомендации
#
# ### Для новичков:
# 1. ✅ Начните с **GPT-4o-mini** - он быстрый, дешевый и достаточно умный
# 2. ✅ Экспериментируйте с **system промптами** - это самый простой способ улучшить результаты
# 3. ✅ Используйте **temperature=0** для задач, где важна точность
# 4. ✅ Всегда проверяйте `finish_reason` - понимайте почему модель остановилась
# 5. ✅ Следите за токенами - они равны деньгам!
#
# ### Для практики:
# 1. 🔨 Создайте простого чат-бота с историей
# 2. 🔨 Попробуйте разные модели на одной и той же задаче
# 3. 🔨 Поэкспериментируйте с разными system промптами
# 4. 🔨 Реализуйте функцию управления историей
# 5. 🔨 Постройте классификатор текста или экстрактор данных
#
# ### Лучшие практики:
# - 🎯 Начинайте с простых решений (не усложняйте раньше времени)
# - 🎯 Тестируйте на реальных данных (синтетические примеры могут обманывать)
# - 🎯 Логируйте все запросы (для дебага и улучшения промптов)
# - 🎯 Обрабатывайте ошибки (API может быть недоступен)
# - 🎯 Считайте стоимость (особенно при масштабировании)
#
# ---
#
# ## 🎓 Поздравляем!
#
# Вы освоили основы работы с OpenAI API! Теперь вы можете:
# - ✅ Отправлять запросы к разным моделям
# - ✅ Управлять поведением через параметры
# - ✅ Работать с ролями и историей диалога
# - ✅ Легко переключаться между провайдерами
# - ✅ Сравнивать модели и выбирать подходящую
#
# **Продолжайте учиться, экспериментировать и создавать! 🚀**
#
# ---
#
# ### 📝 Обратная связь
#
# Если у вас есть вопросы или предложения по улучшению этого notebook, не стесняйтесь обращаться!
#
# **Успехов в изучении LLM и создании ИИ-приложений! 🎉**
